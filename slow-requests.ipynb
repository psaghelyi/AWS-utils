# %% [markdown]
# # Executing AWS CloudWatch Queries

# %%
# %pip install pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/site-packages (2.1.3)
# Requirement already satisfied: numpy<2,>=1.22.4 in /usr/local/lib/python3.10/site-packages (from pandas) (1.26.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/psaghelyi-remote/Library/Python/3.10/lib/python/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import boto3
import subprocess
import json
import os
import time
import pandas as pd

# %% [markdown]
# ## Step 1: Create session and client

# %%
def set_aws_credentials(profile, region_name='us-east-1'):
    result = subprocess.run(f"aws-vault exec {profile} --json", shell=True, capture_output=True)
    credentials = json.loads(result.stdout)

    # Create a session with the retrieved credentials
    session = boto3.session.Session(
        aws_access_key_id=credentials['AccessKeyId'],
        aws_secret_access_key=credentials['SecretAccessKey'],
        aws_session_token=credentials['SessionToken'],
        region_name=region_name        
    )

    return session

# Use the function with your profile to get a session
aws_session = set_aws_credentials('acl-production', 'ca-central-1')

# Create clients using the session
sts_client = aws_session.client('sts')
logs_client = aws_session.client('logs')

# Example usage of the clients
account_id = sts_client.get_caller_identity()["Account"]
print("Current AWS Account ID:", account_id)
# Out:
# Current AWS Account ID: 707785685172

# %%
def current_timestamp():
    return int(time.time() * 1000)

def hours_ago(hours):
    return int(time.time() - 60 * 60 * hours)

def days_ago(days):
    return int(time.time() - 60 * 60 * 24 * days)

# %%
# Define your query
def execute_query(log_group, query, start_time, end_time):
    response = logs_client.start_query(
        logGroupName=log_group,
        startTime=start_time,
        endTime=end_time,
        queryString=query,
    )
    return response['queryId']

def wait_for_query(query_id):
    done = False
    while not done:
        stats = logs_client.get_query_results(queryId=query_id)
        status = stats['status']
        if status == 'Complete':
            print("Query completed.")
            done = True
        elif status == 'Running':
            print("Query still running...")
        elif status == 'Scheduled':
            print("Query scheduled...")
        else:
            print(f"Query status: {status}")
        time.sleep(1)

def get_query_results(query_id):
    response = logs_client.get_query_results(queryId=query_id)
    return response['results'], int(response['statistics']['recordsScanned']), int(response['statistics']['recordsMatched'])


def cloudwatch_query(log_group, query, start_time=current_timestamp(), end_time=hours_ago(1)):
    query_id = execute_query(log_group, query, start_time, end_time)
    wait_for_query(query_id)
    response, records_scanned, records_matched = get_query_results(query_id)
    print (f'records_scanned: {records_scanned}')
    print (f'records_matched: {records_matched}')

    # Flatten the data
    data = []
    for entry in response:
        row = {item['field']: item['value'] for item in entry}
        data.append(row)
    return data

# %%
def parse_messages(data):
    # Parse the @message field in each entry
    for entry in data:
        message_json = entry["@message"]
        
        # Parse the JSON string in @message field
        try:
            message_data = json.loads(message_json)
        except:
            continue
        
        entry["@message"] = message_data

# %% [markdown]
# ## Collect the request ids

# %%
def collect_request_ids(data):
    request_ids = []

    # Iterate over the entries and extract the request_id and x_request_id
    for entry in data:
        message = entry["@message"]
        x_request_id = message.get("x_request_id", None)
        x_nginx_id = message.get("x_nginx_id", None)

        if x_request_id or x_nginx_id:
            if x_request_id:
                request_ids.append(x_request_id)
            if x_nginx_id != x_request_id:
                request_ids.append(x_nginx_id)

    return request_ids

# %% [markdown]
# ## Collect slow queries and corresponding request ids

# %%
log_group = 'projects-main'
#log_group =  'api_proxy-main'

query = "fields @timestamp, @message \
    | filter request_time > 5 \
    | sort @timestamp desc \
    | limit 100"

data = cloudwatch_query(log_group, query, start_time=days_ago(3))
parse_messages(data)
print (json.dumps(data, indent=4))
# Out:
# Query still running...
# Query still running...
# Query still running...
# Query still running...
# Query completed.
# records_scanned: 4566476
# records_matched: 837
# [
#     {
#         "@timestamp": "2023-11-24 12:59:48.898",
#         "@message": {
#             "time_local": "24/Nov/2023:12:59:48 +0000",
#             "client": "10.184.254.250",
#             "ACL_Cloudfront": "",
#             "method": "GET",
#             "scheme": "http",
#             "host": "fortunasilverminesinc.projects-ca.highbond.com",
#             "request": "GET /task_tracker/request_items?page%5Bnumber%5D=1&filter%5Bstatus%5D=false&filter%5Bresponsible_name%5D=Yvette%20Dona%20Fortuna%20Anaky&filter%5Brequestor_id%5D=5366&sort%5Bcolumn%5D=request_items.due_date&sort%5Border%5D=asc HTTP/1.1",
#             "request_length": "4368",
#             "status": "200",
#             "bytes_sent": "11757",
#             "body_bytes_sent": "10276",
#             "referrer": "https://fortunasilverminesinc.projects-ca.highbond.com/task_tracker/request_items",
#             "user_agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36 Edg/119.0.0.0",
#             "request_time": "8.090",
#             "remote_user": "",
#             "x_nginx_id": "0a2efd7f42ecb65715e66ee4212d86f7",
#             "x_request_id": "0a2efd7f42ecb65715e66ee4212d86f7",
#             "upstream_status": "200",
#             "upstream_response_time": "8.092",
#             "upstream_connect_time": "0.004",
#             "upstream_header_time": "8.092"
#         },
#         "@ptr": "ClwKHgoaNzA3Nzg1Njg1MTcyOnByb2plY3RzLW1haW4QBhI2GhgCBlDsoHYAAAACMRdliwAGVgnc8AAAAWIgASjx0aGLwDEwgpCqi8AxOEVAwZwBSLdXUN9CGAAgARA4GAE="
#     },
#     {
#         "@timestamp": "2023-11-24 12:59:48.491",
#         "@message": {
#             "time_local": "24/Nov/2023:12:59:48 +0000",
#             "client": "10.184.254.250",
#             "ACL_Cloudfront": "",
#             "method": "GET",
#             "scheme": "http",
#             "host": "fortunasilverminesinc.projects-ca.highbond.com",
#             "request": "GET /task_tracker/request_items?page%5Bnumber%5D=1&filter%5Bstatus%5D=false&filter%5Baudit_id%5D=10195&filter%5Bresponsible_name%5D=Yvette%20Dona%20Fortuna%20Anaky&filter%5Brequestor_id%5D=5366&sort%5Bcolumn%5D=request_items.due_date&sort%5Border%5D=asc HTTP/1.1",
#             "request_length": "4395",
#             "status": "200",
#             "bytes_sent": "11942",
#             "body_bytes_sent": "10461",
#             "referrer": "https://fortunasilverminesinc.projects-ca.highbond.com/task_tracker/request_items",
#             "user_agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36 Edg/119.0.0.0",
#             "request_time": "6.060",
#             "remote_user": "",
#             "x_nginx_id": "9df3fe8ad68208d1927831d49021ad82",
#             "x_request_id": "9df3fe8ad68208d1927831d49021ad82",
#             "upstream_status": "200",
#             "upstream_response_time": "6.060",
#             "upstream_connect_time": "0.000",
#             "upstream_header_time": "6.060"
#         },
#         "@ptr": "Cl4KHgoaNzA3Nzg1Njg1MTcyOnByb2plY3RzLW1haW4QBxI4GhgCBlWDSYUAAAAARy6pOAAGVgnjAAAABlIgASiR36eLwDEwnfWui8AxOGRAn6cESPOoAVCngQEYACABEBkYAQ=="
#     },
#     {
#         "@timestamp": "2023-11-24 12:59:47.092",
#         "@message": {
#             "time_local": "24/Nov/2023:12:59:47 +0000",
#             "client": "10.184.254.250",
#             "ACL_Cloudfront": "",
#             "method": "GET",
#             "scheme": "http",
#             "host": "fortunasilverminesinc.projects-ca.highbond.com",
#             "request": "GET /task_tracker/request_items?page%5Bnumber%5D=1&filter%5Bstatus%5D=false&filter%5Brequestor_id%5D=5366&sort%5Bcolumn%5D=request_items.due_date&sort%5Border%5D=asc HTTP/1.1",
#             "request_length": "4307",
#             "status": "200",
#             "bytes_sent": "11748",
#             "body_bytes_sent": "10267",
#             "referrer": "https://fortunasilverminesinc.projects-ca.highbond.com/task_tracker/request_items",
#             "user_agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36 Edg/119.0.0.0",
#             "request_time": "7.989",
#             "remote_user": "",
#             "x_nginx_id": "7627cc1caee70964ef5e56648629a677",
#             "x_request_id": "7627cc1caee70964ef5e56648629a677",
#             "upstream_status": "200",
#             "upstream_response_time": "7.988",
#             "upstream_connect_time": "0.000",
#             "upstream_header_time": "7.988"
#         },
#         "@ptr": "Cl4KHgoaNzA3Nzg1Njg1MTcyOnByb2plY3RzLW1haW4QBxI4GhgCBlWDSYUAAAAARy6pOAAGVgnjAAAABlIgASiR36eLwDEwnfWui8AxOGRAn6cESPOoAVCngQEYACABEBgYAQ=="
#     },
#     {
#         "@timestamp": "2023-11-24 12:51:20.215",
#         "@message": {
#             "time_local": "24/Nov/2023:12:51:20 +0000",
#             "client": "10.184.255.194",
#             "ACL_Cloudfront": "",
#             "method": "POST",
#             "scheme": "http",
#             "host": "fortunasilverminesinc.projects-ca.highbond.com",
#             "request": "POST /request_items/52368/attachments HTTP/1.1",
#             "request_length": "14759368",
#             "status": "200",
#             "bytes_sent": "3531",
#             "body_bytes_sent": "2064",
#             "referrer": "https://fortunasilverminesinc.projects-ca.highbond.com/audits/10195/request_items/52368",
#             "user_agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36 Edg/119.0.0.0",
#             "request_time": "21.444",
#             "remote_user": "",
#             "x_nginx_id": "53dc364e9d521f0826dc491184b91b34",
#             "x_request_id": "53dc364e9d521f0826dc491184b91b34",
#             "upstream_status": "200",
#             "upstream_response_time": "2.264",
#             "upstream_connect_time": "0.000",
#             "upstream_header_time": "2.260"
#         },
#         "@ptr": "Cl4KHgoaNzA3Nzg1Njg1MTcyOnByb2plY3RzLW1haW4QAxI4GhgCBlBSA60AAAABlDqcCAAGVgnCYAAABtIgASjG14eLwDEwjPiOi8AxOI0BQPvJA0iwkQFQ6nMYACABEDwYAQ=="
#     },
#     {
#         "@timestamp": "2023-11-24 12:46:32.274",
#         "@message": {
#             "time_local": "24/Nov/2023:12:46:32 +0000",
#             "client": "10.184.255.194",
#             "ACL_Cloudfront": "",
#             "method": "GET",
#             "scheme": "http",
#             "host": "fortunasilverminesinc.projects-ca.highbond.com",
#             "request": "GET /task_tracker/request_items?page%5Bnumber%5D=1&filter%5Bstatus%5D=false&filter%5Baudit_id%5D=10195&sort%5Bcolumn%5D=request_items.due_date&sort%5Border%5D=asc HTTP/1.1",
#             "request_length": "4315",
#             "status": "200",
#             "bytes_sent": "11944",
#             "body_bytes_sent": "10463",
#             "referrer": "https://fortunasilverminesinc.projects-ca.highbond.com/task_tracker/request_items",
#             "user_agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36 Edg/119.0.0.0",
#             "request_time": "6.433",
#             "remote_user": "",
#             "x_nginx_id": "7b54dbf7fce789f177f6f81680df7ed2",
#             "x_request_id": "7b54dbf7fce789f177f6f81680df7ed2",
#             "upstream_status": "200",
#             "upstream_response_time": "6.432",
#             "upstream_connect_time": "0.000",
#             "upstream_header_time": "6.432"
#         },
#         "@ptr": "Cl8KHgoaNzA3Nzg1Njg1MTcyOnByb2plY3RzLW1haW4QBBI5GhgCBlXto7EAAAAAGFoGlQAGVgmp0AAAABIgASjSnPCKwDEw0qr4isAxOJgBQMidBkj91AFQjKgBGAAgARCXARgB"
#     },
#     {
#         "@timestamp": "2023-11-24 12:46:27.675",
#         "@message": {
#             "time_local": "24/Nov/2023:12:46:27 +0000",
#             "client": "10.184.255.194",
#             "ACL_Cloudfront": "",
#             "method": "GET",
#             "scheme": "http",
#             "host": "fortunasilverminesinc.projects-ca.highbond.com",
#             "request": "GET /task_tracker/request_items?page%5Bnumber%5D=1&filter%5Bstatus%5D=false&filter%5Baudit_id%5D=10194&sort%5Bcolumn%5D=request_items.due_date&sort%5Border%5D=asc HTTP/1.1",
#             "request_length": "4315",
#             "status": "200",
#             "bytes_sent": "11548",
#             "body_bytes_sent": "10067",
#             "referrer": "https://fortunasilverminesinc.projects-ca.highbond.com/task_tracker/request_items",
#             "user_agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36 Edg/119.0.0.0",
#             "request_time": "6.342",
#             "remote_user": "",
#             "x_nginx_id": "454c38f608cd8e7c94d783e783d3bc64",
#             "x_request_id": "454c38f608cd8e7c94d783e783d3bc64",
#             "upstream_status": "200",
#             "upstream_response_time": "6.340",
#             "upstream_connect_time": "0.000",
#             "upstream_header_time": "6.340"
#         },
#         "@ptr": "Cl8KHgoaNzA3Nzg1Njg1MTcyOnByb2plY3RzLW1haW4QAhI5GhgCBlJqOC0AAAABnDs8kwAGVgmyIAAAANIgASie6veKwDEwmOL+isAxOJQBQJ33A0j4qwFQ1okBGAAgARAKGAE="
#     },
#     {
#         "@timestamp": "2023-11-24 12:46:24.598",
#         "@message": {
#             "time_local": "24/Nov/2023:12:46:24 +0000",
#             "client": "10.184.255.194",
#             "ACL_Cloudfront": "",
#             "method": "GET",
#             "scheme": "http",
#             "host": "fortunasilverminesinc.projects-ca.highbond.com",
#             "request": "GET /task_tracker/request_items?page%5Bnumber%5D=1&filter%5Bstatus%5D=false&sort%5Bcolumn%5D=request_items.due_date&sort%5Border%5D=asc HTTP/1.1",
#             "request_length": "4288",
#             "status": "200",
#             "bytes_sent": "11939",
#             "body_bytes_sent": "10458",
#             "referrer": "https://fortunasilverminesinc.projects-ca.highbond.com/task_tracker/request_items",
#             "user_agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36 Edg/119.0.0.0",
#             "request_time": "5.988",
#             "remote_user": "",
#             "x_nginx_id": "90c5d50eb1a75dfde2c9a013ad3f91fe",
#             "x_request_id": "90c5d50eb1a75dfde2c9a013ad3f91fe",
#             "upstream_status": "200",
#             "upstream_response_time": "5.988",
#             "upstream_connect_time": "0.000",
#             "upstream_header_time": "5.988"
#         },
#         "@ptr": "Cl8KHgoaNzA3Nzg1Njg1MTcyOnByb2plY3RzLW1haW4QBxI5GhgCBlWDSYUAAAAARxGAbQAGVgmskAAABlIgASiuxfKKwDEwzIL6isAxOKUBQJOECEiu6AFQvcIBGAAgARBvGAE="
#     },
#     {
#         "@timestamp": "2023-11-24 12:17:52.916",
#         "@message": {
#             "time_local": "24/Nov/2023:12:17:52 +0000",
#             "client": "10.184.254.250",
#             "ACL_Cloudfront": "",
#             "method": "POST",
#             "scheme": "http",
#             "host": "fortunasilverminesinc.projects-ca.highbond.com",
#             "request": "POST /request_items/52295/attachments HTTP/1.1",
#             "request_length": "5664994",
#             "status": "200",
#             "bytes_sent": "3528",
#             "body_bytes_sent": "2061",
#             "referrer": "https://fortunasilverminesinc.projects-ca.highbond.com/audits/10194/request_items/52295",
#             "user_agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36 Edg/119.0.0.0",
#             "request_time": "9.183",
#             "remote_user": "",
#             "x_nginx_id": "9fcebdd50aba78380dff150eebc13e9e",
#             "x_request_id": "9fcebdd50aba78380dff150eebc13e9e",
#             "upstream_status": "200",
#             "upstream_response_time": "1.068",
#             "upstream_connect_time": "0.000",
#             "upstream_header_time": "1.068"
#         },
#         "@ptr": "Cl0KHgoaNzA3Nzg1Njg1MTcyOnByb2plY3RzLW1haW4QAxI3GhgCBlBSA60AAAABlBna2AAGVglHQAAABtIgASiUso+KwDEwr5KWisAxOIIBQPfTAkiUd1C8WhgAIAEQABgB"
#     },
#     {
#         "@timestamp": "2023-11-24 12:17:37.080",
#         "@message": {
#             "time_local": "24/Nov/2023:12:17:37 +0000",
#             "client": "10.184.254.250",
#             "ACL_Cloudfront": "",
#             "method": "POST",
#             "scheme": "http",
#             "host": "fortunasilverminesinc.projects-ca.highbond.com",
#             "request": "POST /request_items/52368/attachments HTTP/1.1",
#             "request_length": "56134094",
#             "status": "200",
#             "bytes_sent": "3525",
#             "body_bytes_sent": "2058",
#             "referrer": "https://fortunasilverminesinc.projects-ca.highbond.com/audits/10195/request_items/52368",
#             "user_agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36 Edg/119.0.0.0",
#             "request_time": "76.199",
#             "remote_user": "",
#             "x_nginx_id": "fbc72879194c56fd861793e91b495d22",
#             "x_request_id": "fbc72879194c56fd861793e91b495d22",
#             "upstream_status": "200",
#             "upstream_response_time": "5.004",
#             "upstream_connect_time": "0.000",
#             "upstream_header_time": "4.988"
#         },
#         "@ptr": "Cl0KHgoaNzA3Nzg1Njg1MTcyOnByb2plY3RzLW1haW4QBhI3GhgCBlDsoHYAAAACMNX9cwAGVgk+MAAAAWIgASi95YaKwDEwqfSOisAxOHVA354CSPWAAVDQYRgAIAEQahgB"
#     },
#     {
#         "@timestamp": "2023-11-24 12:17:00.222",
#         "@message": {
#             "time_local": "24/Nov/2023:12:17:00 +0000",
#             "client": "10.184.255.194",
#             "ACL_Cloudfront": "",
#             "method": "POST",
#             "scheme": "http",
#             "host": "fortunasilverminesinc.projects-ca.highbond.com",
#             "request": "POST /request_items/52368/attachments HTTP/1.1",
#             "request_length": "413692",
#             "status": "400",
#             "bytes_sent": "0",
#             "body_bytes_sent": "0",
#             "referrer": "https://fortunasilverminesinc.projects-ca.highbond.com/audits/10195/request_items/52368",
#             "user_agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36 Edg/119.0.0.0",
#             "request_time": "61.119",
#             "remote_user": "",
#             "x_nginx_id": "73e9173ab240122de312c7bd424517c1",
#             "x_request_id": "73e9173ab240122de312c7bd424517c1",
#             "upstream_status": "",
#             "upstream_response_time": "",
#             "upstream_connect_time": "",
#             "upstream_header_time": ""
#         },
#         "@ptr": "ClsKHgoaNzA3Nzg1Njg1MTcyOnByb2plY3RzLW1haW4QAxI1GhgCBlBSA60AAAABlBfvtwAGVglAIAAABtIgASify4iKwDEwwKuPisAxOCZAll9ImkRQwDMYACABEBAYAQ=="
#     },
#     {
#         "@timestamp": "2023-11-24 12:14:50.310",
#         "@message": {
#             "time_local": "24/Nov/2023:12:14:50 +0000",
#             "client": "10.184.254.250",
#             "ACL_Cloudfront": "",
#             "method": "GET",
#             "scheme": "http",
#             "host": "fortunasilverminesinc.projects-ca.highbond.com",
#             "request": "GET /task_tracker/request_items?page%5Bnumber%5D=1&filter%5Bstatus%5D=false&filter%5Baudit_id%5D=10194&sort%5Bcolumn%5D=request_items.due_date&sort%5Border%5D=asc HTTP/1.1",
#             "request_length": "4315",
#             "status": "200",
#             "bytes_sent": "11548",
#             "body_bytes_sent": "10067",
#             "referrer": "https://fortunasilverminesinc.projects-ca.highbond.com/task_tracker/request_items",
#             "user_agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36 Edg/119.0.0.0",
#             "request_time": "6.331",
#             "remote_user": "",
#             "x_nginx_id": "70fdf80e71b3fbbfa43cdee4bb0ba38b",
#             "x_request_id": "70fdf80e71b3fbbfa43cdee4bb0ba38b",
#             "upstream_status": "200",
#             "upstream_response_time": "6.332",
#             "upstream_connect_time": "0.004",
#             "upstream_header_time": "6.332"
#         },
#         "@ptr": "Cl8KHgoaNzA3Nzg1Njg1MTcyOnByb2plY3RzLW1haW4QARI5GhgCBlQgOQAAAAAA5HljvwAGVgk3oAAAAwIgASjEqYGKwDEw5uKHisAxOIECQKy1B0iK0wFQs68BGAAgARBIGAE="
#     },
#     {
#         "@timestamp": "2023-11-24 12:14:33.374",
#         "@message": {
#             "time_local": "24/Nov/2023:12:14:33 +0000",
#             "client": "10.184.254.250",
#             "ACL_Cloudfront": "",
#             "method": "GET",
#             "scheme": "http",
#             "host": "fortunasilverminesinc.projects-ca.highbond.com",
#             "request": "GET /task_tracker/request_items?page%5Bnumber%5D=1&filter%5Bstatus%5D=false&filter%5Baudit_id%5D=10194&sort%5Bcolumn%5D=request_items.due_date&sort%5Border%5D=asc HTTP/1.1",
#             "request_length": "4315",
#             "status": "200",
#             "bytes_sent": "11548",
#             "body_bytes_sent": "10067",
#             "referrer": "https://fortunasilverminesinc.projects-ca.highbond.com/task_tracker/request_items",
#             "user_agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36 Edg/119.0.0.0",
#             "request_time": "7.969",
#             "remote_user": "",
#             "x_nginx_id": "ade5a408a032d83cafbee3fd6acb8927",
#             "x_request_id": "ade5a408a032d83cafbee3fd6acb8927",
#             "upstream_status": "200",
#             "upstream_response_time": "7.968",
#             "upstream_connect_time": "0.000",
#             "upstream_header_time": "7.968"
#         },
#         "@ptr": "Cl8KHgoaNzA3Nzg1Njg1MTcyOnByb2plY3RzLW1haW4QAhI5GhgCBlJqOC0AAAABm/nhNAAGVgk3EAAAANIgASiq4/+JwDEwq7KHisAxOK8BQO7wBUjQzAFQiqYBGAAgARAcGAE="
#     },
#     {
#         "@timestamp": "2023-11-24 12:14:28.996",
#         "@message": {
#             "time_local": "24/Nov/2023:12:14:28 +0000",
#             "client": "10.184.254.250",
#             "ACL_Cloudfront": "",
#             "method": "GET",
#             "scheme": "http",
#             "host": "fortunasilverminesinc.projects-ca.highbond.com",
#             "request": "GET /task_tracker/request_items?page%5Bnumber%5D=1&filter%5Bstatus%5D=false&filter%5Baudit_id%5D=10195&sort%5Bcolumn%5D=request_items.due_date&sort%5Border%5D=asc HTTP/1.1",
#             "request_length": "4315",
#             "status": "200",
#             "bytes_sent": "11944",
#             "body_bytes_sent": "10463",
#             "referrer": "https://fortunasilverminesinc.projects-ca.highbond.com/task_tracker/request_items",
#             "user_agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36 Edg/119.0.0.0",
#             "request_time": "6.362",
#             "remote_user": "",
#             "x_nginx_id": "db1d1e0b01d1dd1de9be866af2f161b3",
#             "x_request_id": "db1d1e0b01d1dd1de9be866af2f161b3",
#             "upstream_status": "200",
#             "upstream_response_time": "6.360",
#             "upstream_connect_time": "0.000",
#             "upstream_header_time": "6.360"
#         },
#         "@ptr": "Cl8KHgoaNzA3Nzg1Njg1MTcyOnByb2plY3RzLW1haW4QARI5GhgCBlQgOQAAAAAA5HljvwAGVgk3oAAAAwIgASjEqYGKwDEw5uKHisAxOIECQKy1B0iK0wFQs68BGAAgARAPGAE="
#     },
#     {
#         "@timestamp": "2023-11-24 12:14:25.759",
#         "@message": {
#             "time_local": "24/Nov/2023:12:14:25 +0000",
#             "client": "10.184.254.250",
#             "ACL_Cloudfront": "",
#             "method": "GET",
#             "scheme": "http",
#             "host": "fortunasilverminesinc.projects-ca.highbond.com",
#             "request": "GET /task_tracker/request_items?page%5Bnumber%5D=1&filter%5Bstatus%5D=false&sort%5Bcolumn%5D=request_items.due_date&sort%5Border%5D=asc HTTP/1.1",
#             "request_length": "4288",
#             "status": "200",
#             "bytes_sent": "11939",
#             "body_bytes_sent": "10458",
#             "referrer": "https://fortunasilverminesinc.projects-ca.highbond.com/task_tracker/request_items",
#             "user_agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36 Edg/119.0.0.0",
#             "request_time": "6.269",
#             "remote_user": "",
#             "x_nginx_id": "cfa305aa502ea572061058dfaa0fd9a7",
#             "x_request_id": "cfa305aa502ea572061058dfaa0fd9a7",
#             "upstream_status": "200",
#             "upstream_response_time": "6.268",
#             "upstream_connect_time": "0.000",
#             "upstream_header_time": "6.268"
#         },
#         "@ptr": "Cl8KHgoaNzA3Nzg1Njg1MTcyOnByb2plY3RzLW1haW4QBxI5GhgCBlWDSYUAAAAARs+6/QAGVgkycAAABlIgASjxpvuJwDEwgvmCisAxOMUBQJKOBEi1qgFQw4oBGAAgARC+ARgB"
#     },
#     {
#         "@timestamp": "2023-11-24 12:05:10.712",
#         "@message": {
#             "time_local": "24/Nov/2023:12:05:10 +0000",
#             "client": "10.184.254.250",
#             "ACL_Cloudfront": "",
#             "method": "POST",
#             "scheme": "http",
#             "host": "fortunasilverminesinc.projects-ca.highbond.com",
#             "request": "POST /request_items/52295/attachments HTTP/1.1",
#             "request_length": "5664994",
#             "status": "200",
#             "bytes_sent": "3539",
#             "body_bytes_sent": "2072",
#             "referrer": "https://fortunasilverminesinc.projects-ca.highbond.com/audits/10194/request_items/52295",
#             "user_agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36 Edg/119.0.0.0",
#             "request_time": "12.425",
#             "remote_user": "",
#             "x_nginx_id": "34fe432383fa4b06bdb36373f940148e",
#             "x_request_id": "34fe432383fa4b06bdb36373f940148e",
#             "upstream_status": "200",
#             "upstream_response_time": "1.172",
#             "upstream_connect_time": "0.000",
#             "upstream_header_time": "1.168"
#         },
#         "@ptr": "Cl8KHgoaNzA3Nzg1Njg1MTcyOnByb2plY3RzLW1haW4QBxI5GhgCBlWDSYUAAAAARr6hRAAGVgkSoAAABlIgASjEmNyJwDEwrbrjicAxONsBQKP4BUiOuwFQ3pgBGAAgARCTARgB"
#     },
#     {
#         "@timestamp": "2023-11-24 11:38:56.409",
#         "@message": {
#             "time_local": "24/Nov/2023:11:38:56 +0000",
#             "client": "10.184.255.194",
#             "ACL_Cloudfront": "",
#             "method": "GET",
#             "scheme": "http",
#             "host": "fortunasilverminesinc.projects-ca.highbond.com",
#             "request": "GET /task_tracker/request_items?page%5Bnumber%5D=1&filter%5Bquery%5D=amc&filter%5Baudit_id%5D=10195&sort%5Bcolumn%5D=request_items.due_date&sort%5Border%5D=desc HTTP/1.1",
#             "request_length": "3156",
#             "status": "200",
#             "bytes_sent": "7894",
#             "body_bytes_sent": "6413",
#             "referrer": "https://fortunasilverminesinc.projects-ca.highbond.com/task_tracker/request_items",
#             "user_agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36 Edg/119.0.0.0",
#             "request_time": "6.476",
#             "remote_user": "",
#             "x_nginx_id": "068a1e73011d1ea588e290c57883c04d",
#             "x_request_id": "068a1e73011d1ea588e290c57883c04d",
#             "upstream_status": "200",
#             "upstream_response_time": "6.476",
#             "upstream_connect_time": "0.004",
#             "upstream_header_time": "6.476"
#         },
#         "@ptr": "ClsKHgoaNzA3Nzg1Njg1MTcyOnByb2plY3RzLW1haW4QABI1GhgCBlP2+PQAAAABNyTX1QAGVgivsAAAAEIgASjI8fuIwDEwx72BicAxOC5As3JIsFFQ2TwYACABECUYAQ=="
#     },
#     {
#         "@timestamp": "2023-11-24 11:30:13.304",
#         "@message": {
#             "time_local": "24/Nov/2023:11:30:13 +0000",
#             "client": "10.184.255.194",
#             "ACL_Cloudfront": "",
#             "method": "GET",
#             "scheme": "http",
#             "host": "fortunasilverminesinc.projects-ca.highbond.com",
#             "request": "GET /task_tracker/request_items?page%5Bnumber%5D=1&filter%5Bquery%5D=rft%20population&sort%5Bcolumn%5D=request_items.due_date&sort%5Border%5D=desc HTTP/1.1",
#             "request_length": "4428",
#             "status": "200",
#             "bytes_sent": "7049",
#             "body_bytes_sent": "5568",
#             "referrer": "https://fortunasilverminesinc.projects-ca.highbond.com/task_tracker/request_items",
#             "user_agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36 Edg/119.0.0.0",
#             "request_time": "5.920",
#             "remote_user": "",
#             "x_nginx_id": "aecd34ab41d964b7fa4a6dccd0521694",
#             "x_request_id": "aecd34ab41d964b7fa4a6dccd0521694",
#             "upstream_status": "200",
#             "upstream_response_time": "5.920",
#             "upstream_connect_time": "0.000",
#             "upstream_header_time": "5.920"
#         },
#         "@ptr": "Cl0KHgoaNzA3Nzg1Njg1MTcyOnByb2plY3RzLW1haW4QAhI3GhgCBlJqOC0AAAABm6O1SQAGVgiRwAAAANIgASiUrt6IwDEwnNPliMAxOFRA54UCSLKEAVC5ZxgAIAEQIRgB"
#     },
#     {
#         "@timestamp": "2023-11-24 11:29:35.774",
#         "@message": {
#             "time_local": "24/Nov/2023:11:29:35 +0000",
#             "client": "10.184.255.194",
#             "ACL_Cloudfront": "",
#             "method": "GET",
#             "scheme": "http",
#             "host": "fortunasilverminesinc.projects-ca.highbond.com",
#             "request": "GET /task_tracker/request_items?page%5Bnumber%5D=1&filter%5Bquery%5D=rft&sort%5Bcolumn%5D=request_items.due_date&sort%5Border%5D=desc HTTP/1.1",
#             "request_length": "4415",
#             "status": "200",
#             "bytes_sent": "12779",
#             "body_bytes_sent": "11298",
#             "referrer": "https://fortunasilverminesinc.projects-ca.highbond.com/task_tracker/request_items",
#             "user_agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36 Edg/119.0.0.0",
#             "request_time": "6.968",
#             "remote_user": "",
#             "x_nginx_id": "f475cf705f7c9d25b6d934b28c170833",
#             "x_request_id": "f475cf705f7c9d25b6d934b28c170833",
#             "upstream_status": "200",
#             "upstream_response_time": "6.968",
#             "upstream_connect_time": "0.000",
#             "upstream_header_time": "6.968"
#         },
#         "@ptr": "Cl0KHgoaNzA3Nzg1Njg1MTcyOnByb2plY3RzLW1haW4QAhI3GhgCBlJqOC0AAAABm6O1SQAGVgiRwAAAANIgASiUrt6IwDEwnNPliMAxOFRA54UCSLKEAVC5ZxgAIAEQARgB"
#     },
#     {
#         "@timestamp": "2023-11-24 11:29:22.578",
#         "@message": {
#             "time_local": "24/Nov/2023:11:29:22 +0000",
#             "client": "10.184.255.194",
#             "ACL_Cloudfront": "",
#             "method": "GET",
#             "scheme": "http",
#             "host": "fortunasilverminesinc.projects-ca.highbond.com",
#             "request": "GET /task_tracker/request_items?page%5Bnumber%5D=1&filter%5Bstatus%5D=false&filter%5Baudit_id%5D=10194&filter%5Bresponsible_name%5D=Yvette%20Dona%20Fortuna%20Anaky&filter%5Brequestor_id%5D=5366&sort%5Bcolumn%5D=request_items.due_date&sort%5Border%5D=asc HTTP/1.1",
#             "request_length": "4395",
#             "status": "200",
#             "bytes_sent": "11520",
#             "body_bytes_sent": "10039",
#             "referrer": "https://fortunasilverminesinc.projects-ca.highbond.com/task_tracker/request_items",
#             "user_agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36 Edg/119.0.0.0",
#             "request_time": "6.604",
#             "remote_user": "",
#             "x_nginx_id": "7560e254ff09e15a8bf1190a2848ed43",
#             "x_request_id": "7560e254ff09e15a8bf1190a2848ed43",
#             "upstream_status": "200",
#             "upstream_response_time": "6.604",
#             "upstream_connect_time": "0.000",
#             "upstream_header_time": "6.600"
#         },
#         "@ptr": "Cl0KHgoaNzA3Nzg1Njg1MTcyOnByb2plY3RzLW1haW4QBhI3GhgCBlDsoHYAAAACMI+k9AAGVgiL4AAAAWIgASjA1NiIwDEwyePgiMAxOHdAidYCSLOOAVDIbBgAIAEQKRgB"
#     },
#     {
#         "@timestamp": "2023-11-24 11:29:19.587",
#         "@message": {
#             "time_local": "24/Nov/2023:11:29:19 +0000",
#             "client": "10.184.255.194",
#             "ACL_Cloudfront": "",
#             "method": "GET",
#             "scheme": "http",
#             "host": "fortunasilverminesinc.projects-ca.highbond.com",
#             "request": "GET /task_tracker/request_items?page%5Bnumber%5D=1&filter%5Bstatus%5D=false&filter%5Bresponsible_name%5D=Yvette%20Dona%20Fortuna%20Anaky&filter%5Brequestor_id%5D=5366&sort%5Bcolumn%5D=request_items.due_date&sort%5Border%5D=asc HTTP/1.1",
#             "request_length": "4368",
#             "status": "200",
#             "bytes_sent": "11757",
#             "body_bytes_sent": "10276",
#             "referrer": "https://fortunasilverminesinc.projects-ca.highbond.com/task_tracker/request_items",
#             "user_agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36 Edg/119.0.0.0",
#             "request_time": "6.627",
#             "remote_user": "",
#             "x_nginx_id": "ea4e1d32a39861ef0f2c0386f7fe4c50",
#             "x_request_id": "ea4e1d32a39861ef0f2c0386f7fe4c50",
#             "upstream_status": "200",
#             "upstream_response_time": "6.624",
#             "upstream_connect_time": "0.000",
#             "upstream_header_time": "6.624"
#         },
#         "@ptr": "Cl4KHgoaNzA3Nzg1Njg1MTcyOnByb2plY3RzLW1haW4QBRI4GhgCBlLuIgQAAAACnp7pWgAGVgiJwAAAA0IgASjbtNeIwDEw5LreiMAxOFJAiuYCSI6lAVCvhQEYACABEEcYAQ=="
#     },
#     {
#         "@timestamp": "2023-11-24 11:29:16.492",
#         "@message": {
#             "time_local": "24/Nov/2023:11:29:16 +0000",
#             "client": "10.184.255.194",
#             "ACL_Cloudfront": "",
#             "method": "GET",
#             "scheme": "http",
#             "host": "fortunasilverminesinc.projects-ca.highbond.com",
#             "request": "GET /task_tracker/request_items?page%5Bnumber%5D=1&sort%5Bcolumn%5D=request_items.due_date&sort%5Border%5D=desc HTTP/1.1",
#             "request_length": "4393",
#             "status": "200",
#             "bytes_sent": "12630",
#             "body_bytes_sent": "11149",
#             "referrer": "https://fortunasilverminesinc.projects-ca.highbond.com/task_tracker/request_items",
#             "user_agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36 Edg/119.0.0.0",
#             "request_time": "5.298",
#             "remote_user": "",
#             "x_nginx_id": "51dba7beb341d287a4a587513a65f4df",
#             "x_request_id": "51dba7beb341d287a4a587513a65f4df",
#             "upstream_status": "200",
#             "upstream_response_time": "5.296",
#             "upstream_connect_time": "0.000",
#             "upstream_header_time": "5.296"
#         },
#         "@ptr": "Cl4KHgoaNzA3Nzg1Njg1MTcyOnByb2plY3RzLW1haW4QBxI4GhgCBlWDSYUAAAAARngX0gAGVgiQEAAABlIgASjYyNyIwDEwqbjkiMAxOIkBQNySA0iQkgFQu3AYACABEAsYAQ=="
#     },
#     {
#         "@timestamp": "2023-11-24 11:29:15.342",
#         "@message": {
#             "time_local": "24/Nov/2023:11:29:15 +0000",
#             "client": "10.184.255.194",
#             "ACL_Cloudfront": "",
#             "method": "GET",
#             "scheme": "http",
#             "host": "fortunasilverminesinc.projects-ca.highbond.com",
#             "request": "GET /task_tracker/request_items?page%5Bnumber%5D=1&filter%5Bstatus%5D=false&sort%5Bcolumn%5D=request_items.due_date&sort%5Border%5D=desc HTTP/1.1",
#             "request_length": "4418",
#             "status": "200",
#             "bytes_sent": "12900",
#             "body_bytes_sent": "11419",
#             "referrer": "https://fortunasilverminesinc.projects-ca.highbond.com/task_tracker/request_items",
#             "user_agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36 Edg/119.0.0.0",
#             "request_time": "5.731",
#             "remote_user": "",
#             "x_nginx_id": "b171ba1afa02b7ead4a703e19d11527c",
#             "x_request_id": "b171ba1afa02b7ead4a703e19d11527c",
#             "upstream_status": "200",
#             "upstream_response_time": "5.732",
#             "upstream_connect_time": "0.000",
#             "upstream_header_time": "5.732"
#         },
#         "@ptr": "Cl4KHgoaNzA3Nzg1Njg1MTcyOnByb2plY3RzLW1haW4QAhI4GhgCBlJqOC0AAAABm59gHQAGVgiJ4AAAANIgASjF0taIwDEwgozeiMAxOLUBQNSZA0imigFQxmwYACABEKcBGAE="
#     },
#     {
#         "@timestamp": "2023-11-24 11:29:15.033",
#         "@message": {
#             "time_local": "24/Nov/2023:11:29:15 +0000",
#             "client": "10.184.255.194",
#             "ACL_Cloudfront": "",
#             "method": "GET",
#             "scheme": "http",
#             "host": "fortunasilverminesinc.projects-ca.highbond.com",
#             "request": "GET /task_tracker/request_items?page%5Bnumber%5D=1&filter%5Bstatus%5D=false&filter%5Brequestor_id%5D=5366&sort%5Bcolumn%5D=request_items.due_date&sort%5Border%5D=asc HTTP/1.1",
#             "request_length": "4307",
#             "status": "200",
#             "bytes_sent": "11748",
#             "body_bytes_sent": "10267",
#             "referrer": "https://fortunasilverminesinc.projects-ca.highbond.com/task_tracker/request_items",
#             "user_agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36 Edg/119.0.0.0",
#             "request_time": "6.730",
#             "remote_user": "",
#             "x_nginx_id": "4ec7fbc4fd322ca85ecfddf673aef98d",
#             "x_request_id": "4ec7fbc4fd322ca85ecfddf673aef98d",
#             "upstream_status": "200",
#             "upstream_response_time": "6.728",
#             "upstream_connect_time": "0.000",
#             "upstream_header_time": "6.724"
#         },
#         "@ptr": "Cl0KHgoaNzA3Nzg1Njg1MTcyOnByb2plY3RzLW1haW4QBhI3GhgCBlDsoHYAAAACMI+k9AAGVgiL4AAAAWIgASjA1NiIwDEwyePgiMAxOHdAidYCSLOOAVDIbBgAIAEQHRgB"
#     },
#     {
#         "@timestamp": "2023-11-24 11:13:08.272",
#         "@message": {
#             "time_local": "24/Nov/2023:11:13:08 +0000",
#             "client": "10.184.254.250",
#             "ACL_Cloudfront": "",
#             "method": "GET",
#             "scheme": "http",
#             "host": "fortunasilverminesinc.projects-ca.highbond.com",
#             "request": "GET /task_tracker/request_items?page%5Bnumber%5D=1&filter%5Bstatus%5D=false&filter%5Baudit_id%5D=10195&sort%5Bcolumn%5D=request_items.due_date&sort%5Border%5D=asc HTTP/1.1",
#             "request_length": "4315",
#             "status": "200",
#             "bytes_sent": "11944",
#             "body_bytes_sent": "10463",
#             "referrer": "https://fortunasilverminesinc.projects-ca.highbond.com/task_tracker/request_items",
#             "user_agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36 Edg/119.0.0.0",
#             "request_time": "6.619",
#             "remote_user": "",
#             "x_nginx_id": "e7b0ce40f658624051fcb996d4ee2048",
#             "x_request_id": "e7b0ce40f658624051fcb996d4ee2048",
#             "upstream_status": "200",
#             "upstream_response_time": "6.616",
#             "upstream_connect_time": "0.000",
#             "upstream_header_time": "6.616"
#         },
#         "@ptr": "Cl4KHgoaNzA3Nzg1Njg1MTcyOnByb2plY3RzLW1haW4QBBI4GhgCBlXto7EAAAAAFy9SEQAGVghOYAAAABIgASjUtZyIwDEw6vajiMAxOLABQJPWAkiRiQFQ1W8YACABEJwBGAE="
#     },
#     {
#         "@timestamp": "2023-11-24 11:13:03.169",
#         "@message": {
#             "time_local": "24/Nov/2023:11:13:03 +0000",
#             "client": "10.184.254.250",
#             "ACL_Cloudfront": "",
#             "method": "GET",
#             "scheme": "http",
#             "host": "fortunasilverminesinc.projects-ca.highbond.com",
#             "request": "GET /task_tracker/request_items?page%5Bnumber%5D=1&filter%5Bstatus%5D=false&sort%5Bcolumn%5D=request_items.due_date&sort%5Border%5D=asc HTTP/1.1",
#             "request_length": "4288",
#             "status": "200",
#             "bytes_sent": "11939",
#             "body_bytes_sent": "10458",
#             "referrer": "https://fortunasilverminesinc.projects-ca.highbond.com/task_tracker/request_items",
#             "user_agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36 Edg/119.0.0.0",
#             "request_time": "7.985",
#             "remote_user": "",
#             "x_nginx_id": "c843562ff74cb39666141f65f243a82d",
#             "x_request_id": "c843562ff74cb39666141f65f243a82d",
#             "upstream_status": "200",
#             "upstream_response_time": "7.984",
#             "upstream_connect_time": "0.004",
#             "upstream_header_time": "7.984"
#         },
#         "@ptr": "Cl8KHgoaNzA3Nzg1Njg1MTcyOnByb2plY3RzLW1haW4QAhI5GhgCBlJqOC0AAAABm4EVjQAGVghQIAAAANIgASj8p56IwDEwv6qmiMAxONABQNihBkj8ywFQzacBGAAgARCJARgB"
#     },
#     {
#         "@timestamp": "2023-11-24 09:42:22.799",
#         "@message": {
#             "time_local": "24/Nov/2023:09:42:22 +0000",
#             "client": "10.184.254.250",
#             "ACL_Cloudfront": "",
#             "method": "GET",
#             "scheme": "http",
#             "host": "fortunasilverminesinc.projects-ca.highbond.com",
#             "request": "GET /task_tracker/request_items?page%5Bnumber%5D=1&filter%5Bstatus%5D=false&filter%5Baudit_id%5D=10195&filter%5Bresponsible_name%5D=Yvette%20Dona%20Fortuna%20Anaky&filter%5Brequestor_id%5D=5366&sort%5Bcolumn%5D=request_items.due_date&sort%5Border%5D=asc HTTP/1.1",
#             "request_length": "4396",
#             "status": "200",
#             "bytes_sent": "11911",
#             "body_bytes_sent": "10430",
#             "referrer": "https://fortunasilverminesinc.projects-ca.highbond.com/task_tracker/request_items",
#             "user_agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36 Edg/119.0.0.0",
#             "request_time": "6.263",
#             "remote_user": "",
#             "x_nginx_id": "d6d733d849e75b03de118fe0bc1815fc",
#             "x_request_id": "d6d733d849e75b03de118fe0bc1815fc",
#             "upstream_status": "200",
#             "upstream_response_time": "6.264",
#             "upstream_connect_time": "0.000",
#             "upstream_header_time": "6.264"
#         },
#         "@ptr": "Cl0KHgoaNzA3Nzg1Njg1MTcyOnByb2plY3RzLW1haW4QBRI3GhgCBlLuIgQAAAACne/51wAGVgb6cAAAA0IgASjE0NCFwDEwnffYhcAxOGBA6I0DSMCSAVDVcBgAIAEQPxgB"
#     },
#     {
#         "@timestamp": "2023-11-24 09:42:20.595",
#         "@message": {
#             "time_local": "24/Nov/2023:09:42:20 +0000",
#             "client": "10.184.254.250",
#             "ACL_Cloudfront": "",
#             "method": "GET",
#             "scheme": "http",
#             "host": "fortunasilverminesinc.projects-ca.highbond.com",
#             "request": "GET /task_tracker/request_items?page%5Bnumber%5D=1&filter%5Bstatus%5D=false&filter%5Bresponsible_name%5D=Yvette%20Dona%20Fortuna%20Anaky&filter%5Brequestor_id%5D=5366&sort%5Bcolumn%5D=request_items.due_date&sort%5Border%5D=asc HTTP/1.1",
#             "request_length": "4369",
#             "status": "200",
#             "bytes_sent": "11757",
#             "body_bytes_sent": "10276",
#             "referrer": "https://fortunasilverminesinc.projects-ca.highbond.com/task_tracker/request_items",
#             "user_agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36 Edg/119.0.0.0",
#             "request_time": "6.110",
#             "remote_user": "",
#             "x_nginx_id": "e286a7f88dd9b331d085ad66e1bb6cd4",
#             "x_request_id": "e286a7f88dd9b331d085ad66e1bb6cd4",
#             "upstream_status": "200",
#             "upstream_response_time": "6.112",
#             "upstream_connect_time": "0.004",
#             "upstream_header_time": "6.112"
#         },
#         "@ptr": "Cl8KHgoaNzA3Nzg1Njg1MTcyOnByb2plY3RzLW1haW4QBhI5GhgCBlDsoHYAAAACL+efMgAGVgb8oAAAAWIgASi02tKFwDEw0oDbhcAxOKEBQMygA0iYoQFQloEBGAAgARBUGAE="
#     },
#     {
#         "@timestamp": "2023-11-24 09:42:14.819",
#         "@message": {
#             "time_local": "24/Nov/2023:09:42:14 +0000",
#             "client": "10.184.254.250",
#             "ACL_Cloudfront": "",
#             "method": "GET",
#             "scheme": "http",
#             "host": "fortunasilverminesinc.projects-ca.highbond.com",
#             "request": "GET /task_tracker/request_items?page%5Bnumber%5D=1&filter%5Bstatus%5D=false&filter%5Brequestor_id%5D=5366&sort%5Bcolumn%5D=request_items.due_date&sort%5Border%5D=asc HTTP/1.1",
#             "request_length": "4308",
#             "status": "200",
#             "bytes_sent": "11748",
#             "body_bytes_sent": "10267",
#             "referrer": "https://fortunasilverminesinc.projects-ca.highbond.com/task_tracker/request_items",
#             "user_agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36 Edg/119.0.0.0",
#             "request_time": "5.743",
#             "remote_user": "",
#             "x_nginx_id": "5df9f0eedb0c037d47b4d5885dd3d577",
#             "x_request_id": "5df9f0eedb0c037d47b4d5885dd3d577",
#             "upstream_status": "200",
#             "upstream_response_time": "5.744",
#             "upstream_connect_time": "0.004",
#             "upstream_header_time": "5.744"
#         },
#         "@ptr": "Cl8KHgoaNzA3Nzg1Njg1MTcyOnByb2plY3RzLW1haW4QBxI5GhgCBlWDSYUAAAAARY7gPgAGVgb7wAAABlIgASio7tGFwDEwy57ZhcAxOKoBQNHsAki+ngFQwYIBGAAgARAVGAE="
#     },
#     {
#         "@timestamp": "2023-11-24 09:15:54.636",
#         "@message": {
#             "time_local": "24/Nov/2023:09:15:54 +0000",
#             "client": "10.184.254.250",
#             "ACL_Cloudfront": "",
#             "method": "GET",
#             "scheme": "http",
#             "host": "fortunasilverminesinc.projects-ca.highbond.com",
#             "request": "GET /task_tracker/request_items?page%5Bnumber%5D=1&filter%5Bstatus%5D=false&filter%5Baudit_id%5D=10194&sort%5Bcolumn%5D=request_items.due_date&sort%5Border%5D=asc HTTP/1.1",
#             "request_length": "4315",
#             "status": "200",
#             "bytes_sent": "11548",
#             "body_bytes_sent": "10067",
#             "referrer": "https://fortunasilverminesinc.projects-ca.highbond.com/task_tracker/request_items",
#             "user_agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36 Edg/119.0.0.0",
#             "request_time": "6.218",
#             "remote_user": "",
#             "x_nginx_id": "cb7c92ffa73e6b297b9c74ad8916d073",
#             "x_request_id": "cb7c92ffa73e6b297b9c74ad8916d073",
#             "upstream_status": "200",
#             "upstream_response_time": "6.216",
#             "upstream_connect_time": "0.000",
#             "upstream_header_time": "6.216"
#         },
#         "@ptr": "ClwKHgoaNzA3Nzg1Njg1MTcyOnByb2plY3RzLW1haW4QAhI2GhgCBlJqOC0AAAABmpk17QAGVgaZMAAAANIgASjhzPGEwDEwpof5hMAxOG5Ay68CSKt7ULVhGAAgARApGAE="
#     },
#     {
#         "@timestamp": "2023-11-24 09:15:51.519",
#         "@message": {
#             "time_local": "24/Nov/2023:09:15:51 +0000",
#             "client": "10.184.254.250",
#             "ACL_Cloudfront": "",
#             "method": "GET",
#             "scheme": "http",
#             "host": "fortunasilverminesinc.projects-ca.highbond.com",
#             "request": "GET /task_tracker/request_items?page%5Bnumber%5D=1&filter%5Bstatus%5D=false&filter%5Baudit_id%5D=10195&sort%5Bcolumn%5D=request_items.due_date&sort%5Border%5D=asc HTTP/1.1",
#             "request_length": "4315",
#             "status": "200",
#             "bytes_sent": "11944",
#             "body_bytes_sent": "10463",
#             "referrer": "https://fortunasilverminesinc.projects-ca.highbond.com/task_tracker/request_items",
#             "user_agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36 Edg/119.0.0.0",
#             "request_time": "6.289",
#             "remote_user": "",
#             "x_nginx_id": "43210df4d063351b71bd7c10772d717d",
#             "x_request_id": "43210df4d063351b71bd7c10772d717d",
#             "upstream_status": "200",
#             "upstream_response_time": "6.288",
#             "upstream_connect_time": "0.000",
#             "upstream_header_time": "6.288"
#         },
#         "@ptr": "ClwKHgoaNzA3Nzg1Njg1MTcyOnByb2plY3RzLW1haW4QABI2GhgCBlP2+PQAAAABNgIrjgAGVgaaMAAAAEIgASjBgPOEwDEw5pv3hMAxOF1A6eYBSP91UORYGAAgARBHGAE="
#     },
#     {
#         "@timestamp": "2023-11-24 09:15:49.389",
#         "@message": {
#             "time_local": "24/Nov/2023:09:15:49 +0000",
#             "client": "10.184.254.250",
#             "ACL_Cloudfront": "",
#             "method": "GET",
#             "scheme": "http",
#             "host": "fortunasilverminesinc.projects-ca.highbond.com",
#             "request": "GET /task_tracker/request_items?page%5Bnumber%5D=1&filter%5Bstatus%5D=false&sort%5Bcolumn%5D=request_items.due_date&sort%5Border%5D=asc HTTP/1.1",
#             "request_length": "4288",
#             "status": "200",
#             "bytes_sent": "11939",
#             "body_bytes_sent": "10458",
#             "referrer": "https://fortunasilverminesinc.projects-ca.highbond.com/task_tracker/request_items",
#             "user_agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36 Edg/119.0.0.0",
#             "request_time": "6.199",
#             "remote_user": "",
#             "x_nginx_id": "19fece805706c9bb59fd6e8ce4a9d84e",
#             "x_request_id": "19fece805706c9bb59fd6e8ce4a9d84e",
#             "upstream_status": "200",
#             "upstream_response_time": "6.196",
#             "upstream_connect_time": "0.000",
#             "upstream_header_time": "6.196"
#         },
#         "@ptr": "Cl0KHgoaNzA3Nzg1Njg1MTcyOnByb2plY3RzLW1haW4QBhI3GhgCBlDsoHYAAAACL6VDmQAGVgaV8AAAAWIgASjBvu6EwDEwrM32hMAxOHBAsZoCSLeBAVDwYRgAIAEQZBgB"
#     },
#     {
#         "@timestamp": "2023-11-24 08:12:28.219",
#         "@message": {
#             "time_local": "24/Nov/2023:08:12:28 +0000",
#             "client": "10.184.254.250",
#             "ACL_Cloudfront": "",
#             "method": "POST",
#             "scheme": "http",
#             "host": "fortunasilverminesinc.projects-ca.highbond.com",
#             "request": "POST /request_items/52349/attachments HTTP/1.1",
#             "request_length": "2822353",
#             "status": "200",
#             "bytes_sent": "3615",
#             "body_bytes_sent": "2148",
#             "referrer": "https://fortunasilverminesinc.projects-ca.highbond.com/audits/10195/request_items/52349",
#             "user_agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36 Edg/119.0.0.0",
#             "request_time": "5.783",
#             "remote_user": "",
#             "x_nginx_id": "88d9a4969a26b221dc25f7bfca968211",
#             "x_request_id": "88d9a4969a26b221dc25f7bfca968211",
#             "upstream_status": "200",
#             "upstream_response_time": "0.964",
#             "upstream_connect_time": "0.004",
#             "upstream_header_time": "0.964"
#         },
#         "@ptr": "Cl0KHgoaNzA3Nzg1Njg1MTcyOnByb2plY3RzLW1haW4QARI3GhgCBlQgOQAAAAAA4tjtNQAGVgWsIAAAAwIgASjWi4qDwDEw0I6Rg8AxOHtA7KECSP2FAVDJZxgAIAEQGBgB"
#     },
#     {
#         "@timestamp": "2023-11-24 08:12:12.328",
#         "@message": {
#             "time_local": "24/Nov/2023:08:12:12 +0000",
#             "client": "10.184.254.250",
#             "ACL_Cloudfront": "",
#             "method": "GET",
#             "scheme": "http",
#             "host": "fortunasilverminesinc.projects-ca.highbond.com",
#             "request": "GET /task_tracker/request_items?page%5Bnumber%5D=1&filter%5Bstatus%5D=false&filter%5Baudit_id%5D=10195&filter%5Bresponsible_name%5D=Yvette%20Dona%20Fortuna%20Anaky&filter%5Brequestor_id%5D=5366&sort%5Bcolumn%5D=request_items.due_date&sort%5Border%5D=asc HTTP/1.1",
#             "request_length": "4399",
#             "status": "200",
#             "bytes_sent": "11911",
#             "body_bytes_sent": "10430",
#             "referrer": "https://fortunasilverminesinc.projects-ca.highbond.com/task_tracker/request_items",
# ...
#     },
#     {
#         "@timestamp": "2023-11-23 22:37:07.503",
#         "@message": {
#             "time_local": "23/Nov/2023:22:37:07 +0000",
#             "client": "10.184.254.250",
#             "ACL_Cloudfront": "",
#             "method": "GET",
#             "scheme": "http",
#             "host": "projects-ca.highbond.com",
#             "request": "GET /api/v3/attachments_history/524273?org_id=3138&attempt=1 HTTP/1.1",
#             "request_length": "6614",
#             "status": "200",
#             "bytes_sent": "52899",
#             "body_bytes_sent": "51869",
#             "referrer": "https://nutrien.projects-ca.highbond.com/",
#             "user_agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/118.0.0.0 Safari/537.36 Edg/118.0.2088.76",
#             "request_time": "21.240",
#             "remote_user": "karandeep.grewal@nutrien.com",
#             "x_nginx_id": "3c894fa8e0cb33b6c951d7fcbd0d80c1",
#             "x_request_id": "6303434bfac5f4af04d9cf9645b1dc08",
#             "upstream_status": "200",
#             "upstream_response_time": "21.240",
#             "upstream_connect_time": "0.000",
#             "upstream_header_time": "21.240"
#         },
#         "@ptr": "Cl8KHgoaNzA3Nzg1Njg1MTcyOnByb2plY3RzLW1haW4QBRI5GhgCBlLuIgQAAAACmjBb9gAGVf08EAAAA0IgASjYxMzyvzEwne7T8r8xOIIIQMTtLEjG3AJQ3rwCGAAgARDLAhgB"
#     },
#     {
#         "@timestamp": "2023-11-23 22:37:03.474",
#         "@message": {
#             "time_local": "23/Nov/2023:22:37:03 +0000",
#             "client": "10.184.254.250",
#             "ACL_Cloudfront": "",
#             "method": "GET",
#             "scheme": "http",
#             "host": "projects-ca.highbond.com",
#             "request": "GET /api/v3/issues?org_id=3138&filter%5Bproject.id%5D=10465&filter%5Btarget.type%5D=narratives&filter%5Btarget.id%5D=20410&filter%5Bclosed%5D=false&meta_fields=counters&attempt=1 HTTP/1.1",
#             "request_length": "6732",
#             "status": "200",
#             "bytes_sent": "1117",
#             "body_bytes_sent": "88",
#             "referrer": "https://nutrien.projects-ca.highbond.com/",
#             "user_agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/118.0.0.0 Safari/537.36 Edg/118.0.2088.76",
#             "request_time": "17.039",
#             "remote_user": "karandeep.grewal@nutrien.com",
#             "x_nginx_id": "dd06bc4a8e23fd2ce8054560e5f7e3a3",
#             "x_request_id": "0f8f4704f9e0302e714fcfd061641f25",
#             "upstream_status": "200",
#             "upstream_response_time": "17.036",
#             "upstream_connect_time": "0.000",
#             "upstream_header_time": "17.036"
#         },
#         "@ptr": "Cl8KHgoaNzA3Nzg1Njg1MTcyOnByb2plY3RzLW1haW4QAhI5GhgCBlJqOC0AAAABlT4CEgAGVf1AkAAAANIgASiykdHyvzEw8abY8r8xOOIDQJqrE0i12wJQyrgCGAAgARAwGAE="
#     },
#     {
#         "@timestamp": "2023-11-23 22:37:03.135",
#         "@message": {
#             "time_local": "23/Nov/2023:22:37:03 +0000",
#             "client": "10.184.254.250",
#             "ACL_Cloudfront": "",
#             "method": "GET",
#             "scheme": "http",
#             "host": "projects-ca.highbond.com",
#             "request": "GET /api/v3/attachments_history/528676?org_id=3138&attempt=1 HTTP/1.1",
#             "request_length": "6614",
#             "status": "200",
#             "bytes_sent": "32042",
#             "body_bytes_sent": "31012",
#             "referrer": "https://nutrien.projects-ca.highbond.com/",
#             "user_agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/118.0.0.0 Safari/537.36 Edg/118.0.2088.76",
#             "request_time": "16.854",
#             "remote_user": "karandeep.grewal@nutrien.com",
#             "x_nginx_id": "d24a7b8811f24aebf1eb34825b67baf5",
#             "x_request_id": "1c73e4f3f6f02e55b8e40c6b993eaa8b",
#             "upstream_status": "200",
#             "upstream_response_time": "16.856",
#             "upstream_connect_time": "0.000",
#             "upstream_header_time": "16.856"
#         },
#         "@ptr": "Cl8KHgoaNzA3Nzg1Njg1MTcyOnByb2plY3RzLW1haW4QAhI5GhgCBlJqOC0AAAABlT4CEgAGVf1AkAAAANIgASiykdHyvzEw8abY8r8xOOIDQJqrE0i12wJQyrgCGAAgARAvGAE="
#     },
#     {
#         "@timestamp": "2023-11-23 22:36:25.995",
#         "@message": {
#             "time_local": "23/Nov/2023:22:36:25 +0000",
#             "client": "10.184.254.250",
#             "ACL_Cloudfront": "",
#             "method": "GET",
#             "scheme": "http",
#             "host": "projects-ca.highbond.com",
#             "request": "GET /api/v3/attachments_history/529962?org_id=3138&attempt=1 HTTP/1.1",
#             "request_length": "6531",
#             "status": "200",
#             "bytes_sent": "115245",
#             "body_bytes_sent": "114215",
#             "referrer": "https://nutrien.projects-ca.highbond.com/",
#             "user_agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36",
#             "request_time": "54.680",
#             "remote_user": "holly.matkowski@nutrien.com",
#             "x_nginx_id": "72b4f6c3e989df12266808b4c90c8659",
#             "x_request_id": "19373951cd26ca8e9b214a42946adbd1",
#             "upstream_status": "200",
#             "upstream_response_time": "54.677",
#             "upstream_connect_time": "0.000",
#             "upstream_header_time": "54.677"
#         },
#         "@ptr": "Cl8KHgoaNzA3Nzg1Njg1MTcyOnByb2plY3RzLW1haW4QBxI5GhgCBlWDSYUAAAAAP3PrTwAGVf0+cAAABlIgASiLlM/yvzEw477W8r8xOOQFQMyMHkivlANQiPUCGAAgARAAGAE="
#     },
#     {
#         "@timestamp": "2023-11-23 22:36:05.614",
#         "@message": {
#             "time_local": "23/Nov/2023:22:36:05 +0000",
#             "client": "10.184.255.194",
#             "ACL_Cloudfront": "",
#             "method": "GET",
#             "scheme": "http",
#             "host": "projects-ca.highbond.com",
#             "request": "GET /api/v3/todos?org_id=12851&filter%5Bproject.id%5D=7202&filter%5Btarget.type%5D=controls&filter%5Btarget.id%5D=252967&filter%5Bstatus%5D=open&page%5Bsize%5D=1&meta_fields=counters&attempt=1 HTTP/1.1",
#             "request_length": "7057",
#             "status": "200",
#             "bytes_sent": "1117",
#             "body_bytes_sent": "88",
#             "referrer": "https://teluscorporation-internalaudit.projects-ca.highbond.com/",
#             "user_agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36",
#             "request_time": "6.025",
#             "remote_user": "shilpy.agrawal@telus.com",
#             "x_nginx_id": "e6af12cb0b3de436200630d7df979d7b",
#             "x_request_id": "dbfd5e7fc2318b52ecd650e5bbe527d8",
#             "upstream_status": "200",
#             "upstream_response_time": "6.024",
#             "upstream_connect_time": "0.000",
#             "upstream_header_time": "6.024"
#         },
#         "@ptr": "Cl8KHgoaNzA3Nzg1Njg1MTcyOnByb2plY3RzLW1haW4QABI5GhgCBlP2+PQAAAABMLFrdwAGVf06UAAAAEIgASjA3cryvzEwlpHQ8r8xOJcDQP3vEUjm1AFQ/bUBGAAgARCPAxgB"
#     },
#     {
#         "@timestamp": "2023-11-23 22:36:05.192",
#         "@message": {
#             "time_local": "23/Nov/2023:22:36:05 +0000",
#             "client": "10.184.254.250",
#             "ACL_Cloudfront": "",
#             "method": "GET",
#             "scheme": "http",
#             "host": "projects-ca.highbond.com",
#             "request": "GET /api/v3/controls/252967?org_id=12851&fields%5Bcontrols%5D=custom_attributes%2Cpreparer_signoff%2Ccontrol_id%2Cowner%2Cfrequency%2Ccontrol_type%2Cprevent_detect%2Cmethod%2Cstatus&fields%5Bobjectives%5D=reference&sign_ckeditor_pictures=true&include=objective&attempt=1 HTTP/1.1",
#             "request_length": "7135",
#             "status": "200",
#             "bytes_sent": "1758",
#             "body_bytes_sent": "687",
#             "referrer": "https://teluscorporation-internalaudit.projects-ca.highbond.com/",
#             "user_agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36",
#             "request_time": "5.702",
#             "remote_user": "shilpy.agrawal@telus.com",
#             "x_nginx_id": "10d98761277165aa112510ed95d97be7",
#             "x_request_id": "0282531158366b43e64d2ba8fe789ac5",
#             "upstream_status": "200",
#             "upstream_response_time": "5.700",
#             "upstream_connect_time": "0.000",
#             "upstream_header_time": "5.700"
#         },
#         "@ptr": "Cl8KHgoaNzA3Nzg1Njg1MTcyOnByb2plY3RzLW1haW4QABI5GhgCBlP2+PQAAAABMLFrdwAGVf06UAAAAEIgASjA3cryvzEwlpHQ8r8xOJcDQP3vEUjm1AFQ/bUBGAAgARCOAxgB"
#     },
#     {
#         "@timestamp": "2023-11-23 22:36:04.795",
#         "@message": {
#             "time_local": "23/Nov/2023:22:36:04 +0000",
#             "client": "10.184.255.194",
#             "ACL_Cloudfront": "",
#             "method": "GET",
#             "scheme": "http",
#             "host": "teluscorporation-internalaudit.projects-ca.highbond.com",
#             "request": "GET /audits/7202/objectives/40573/controls/252967/related_entities?collapsed=true&new_workpage_xp=true HTTP/1.1",
#             "request_length": "4553",
#             "status": "200",
#             "bytes_sent": "8090",
#             "body_bytes_sent": "6616",
#             "referrer": "https://teluscorporation-internalaudit.projects-ca.highbond.com/audits/7202/objectives/40573/controls/252967",
#             "user_agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36",
#             "request_time": "5.479",
#             "remote_user": "",
#             "x_nginx_id": "963da6a8159924ce772fca75714dd513",
#             "x_request_id": "963da6a8159924ce772fca75714dd513",
#             "upstream_status": "200",
#             "upstream_response_time": "5.480",
#             "upstream_connect_time": "0.080",
#             "upstream_header_time": "5.480"
#         },
#         "@ptr": "Cl8KHgoaNzA3Nzg1Njg1MTcyOnByb2plY3RzLW1haW4QABI5GhgCBlP2+PQAAAABMLFrdwAGVf06UAAAAEIgASjA3cryvzEwlpHQ8r8xOJcDQP3vEUjm1AFQ/bUBGAAgARCNAxgB"
#     },
#     {
#         "@timestamp": "2023-11-23 22:36:03.393",
#         "@message": {
#             "time_local": "23/Nov/2023:22:36:03 +0000",
#             "client": "10.184.254.250",
#             "ACL_Cloudfront": "",
#             "method": "GET",
#             "scheme": "http",
#             "host": "projects-ca.highbond.com",
#             "request": "GET /api/v3/control_tests/224349?org_id=12851&fields%5Bcontrol_tests%5D=preparer_signoff%2Ctesting_round_number%2Cnot_applicable%2Csample_size%2Cassignee_name%2Ctesting_results%2Ctesting_conclusion%2Ctesting_conclusion_status%2Ccreated_at%2Cupdated_at%2Ccontrol%2Cassigned_user%2Cactual_milestone_date%2Cplanned_milestone_date&fields%5Bcontrol_test_plans%5D=total_sample_size&include=control_test_plan&sign_ckeditor_pictures=true&attempt=1 HTTP/1.1",
#             "request_length": "7304",
#             "status": "200",
#             "bytes_sent": "72693",
#             "body_bytes_sent": "71622",
#             "referrer": "https://teluscorporation-internalaudit.projects-ca.highbond.com/",
#             "user_agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36",
#             "request_time": "8.604",
#             "remote_user": "shilpy.agrawal@telus.com",
#             "x_nginx_id": "5626df9c9e33c719a6af33a977676c6b",
#             "x_request_id": "129f970645952d5997279a9ee12c8f61",
#             "upstream_status": "200",
#             "upstream_response_time": "8.604",
#             "upstream_connect_time": "0.004",
#             "upstream_header_time": "8.604"
#         },
#         "@ptr": "Cl8KHgoaNzA3Nzg1Njg1MTcyOnByb2plY3RzLW1haW4QABI5GhgCBlP2+PQAAAABMLFrdwAGVf06UAAAAEIgASjA3cryvzEwlpHQ8r8xOJcDQP3vEUjm1AFQ/bUBGAAgARCMAxgB"
#     },
#     {
#         "@timestamp": "2023-11-23 22:36:02.906",
#         "@message": {
#             "time_local": "23/Nov/2023:22:36:02 +0000",
#             "client": "10.184.255.194",
#             "ACL_Cloudfront": "",
#             "method": "GET",
#             "scheme": "http",
#             "host": "projects-ca.highbond.com",
#             "request": "GET /api/v3/project_types/1896?org_id=3138&fields%5Bproject_types%5D=narrative_terms&attempt=1 HTTP/1.1",
#             "request_length": "6565",
#             "status": "200",
#             "bytes_sent": "1723",
#             "body_bytes_sent": "694",
#             "referrer": "https://nutrien.projects-ca.highbond.com/",
#             "user_agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36",
#             "request_time": "31.001",
#             "remote_user": "holly.matkowski@nutrien.com",
#             "x_nginx_id": "904502c69ad1d9919b92f0954172fa05",
#             "x_request_id": "4851a6035aaa3c86d720267f1129080f",
#             "upstream_status": "200",
#             "upstream_response_time": "30.997",
#             "upstream_connect_time": "0.000",
#             "upstream_header_time": "30.997"
#         },
#         "@ptr": "Cl8KHgoaNzA3Nzg1Njg1MTcyOnByb2plY3RzLW1haW4QABI5GhgCBlP2+PQAAAABMLFrdwAGVf06UAAAAEIgASjA3cryvzEwlpHQ8r8xOJcDQP3vEUjm1AFQ/bUBGAAgARCLAxgB"
#     },
#     {
#         "@timestamp": "2023-11-23 22:36:02.293",
#         "@message": {
#             "time_local": "23/Nov/2023:22:36:02 +0000",
#             "client": "10.184.255.194",
#             "ACL_Cloudfront": "",
#             "method": "GET",
#             "scheme": "http",
#             "host": "projects-ca.highbond.com",
#             "request": "GET /api/v3/todos?org_id=3138&filter%5Bproject.id%5D=10465&filter%5Btarget.type%5D=narratives&filter%5Btarget.id%5D=20410&filter%5Bstatus%5D=open&page%5Bsize%5D=1&meta_fields=counters&attempt=1 HTTP/1.1",
#             "request_length": "6664",
#             "status": "200",
#             "bytes_sent": "1117",
#             "body_bytes_sent": "88",
#             "referrer": "https://nutrien.projects-ca.highbond.com/",
#             "user_agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36",
#             "request_time": "30.804",
#             "remote_user": "holly.matkowski@nutrien.com",
#             "x_nginx_id": "d90947adf5c74d693c9b0386f274a428",
#             "x_request_id": "20cade6bb48cfbb81f1f279eb7d15644",
#             "upstream_status": "200",
#             "upstream_response_time": "30.801",
#             "upstream_connect_time": "0.000",
#             "upstream_header_time": "30.801"
#         },
#         "@ptr": "Cl8KHgoaNzA3Nzg1Njg1MTcyOnByb2plY3RzLW1haW4QABI5GhgCBlP2+PQAAAABMLFrdwAGVf06UAAAAEIgASjA3cryvzEwlpHQ8r8xOJcDQP3vEUjm1AFQ/bUBGAAgARCKAxgB"
#     },
#     {
#         "@timestamp": "2023-11-23 22:36:00.605",
#         "@message": {
#             "time_local": "23/Nov/2023:22:36:00 +0000",
#             "client": "10.184.254.250",
#             "ACL_Cloudfront": "",
#             "method": "GET",
#             "scheme": "http",
#             "host": "projects-ca.highbond.com",
#             "request": "GET /api/v3/attachments_history/524273?org_id=3138&attempt=1 HTTP/1.1",
#             "request_length": "6531",
#             "status": "200",
#             "bytes_sent": "52746",
#             "body_bytes_sent": "51716",
#             "referrer": "https://nutrien.projects-ca.highbond.com/",
#             "user_agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36",
#             "request_time": "29.239",
#             "remote_user": "holly.matkowski@nutrien.com",
#             "x_nginx_id": "b67fe34f219405be4bb103243e9958c7",
#             "x_request_id": "931bda6571cdf57a229bf1162e3948d5",
#             "upstream_status": "200",
#             "upstream_response_time": "29.237",
#             "upstream_connect_time": "0.024",
#             "upstream_header_time": "29.237"
#         },
#         "@ptr": "Cl8KHgoaNzA3Nzg1Njg1MTcyOnByb2plY3RzLW1haW4QAxI5GhgCBlBSA60AAAABkLmGsAAGVf04wAAABtIgASiNvsnyvzEwu+7P8r8xOMcEQNKFGUi8qgJQk4sCGAAgARDVARgB"
#     }
# ]

# %%
request_ids = collect_request_ids(data)

print (json.dumps(request_ids, indent=4))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/psaghelyi-remote/Project/AWS_logs/us-east-1/slow-requests.ipynb Cell 13 line 1
# ----> <a href='vscode-notebook-cell:/Users/psaghelyi-remote/Project/AWS_logs/us-east-1/slow-requests.ipynb#X15sZmlsZQ%3D%3D?line=0'>1</a> request_ids = collect_request_ids(data)
#       <a href='vscode-notebook-cell:/Users/psaghelyi-remote/Project/AWS_logs/us-east-1/slow-requests.ipynb#X15sZmlsZQ%3D%3D?line=2'>3</a> print (json.dumps(request_ids, indent=4))
#
# /Users/psaghelyi-remote/Project/AWS_logs/us-east-1/slow-requests.ipynb Cell 13 line 6
#       <a href='vscode-notebook-cell:/Users/psaghelyi-remote/Project/AWS_logs/us-east-1/slow-requests.ipynb#X15sZmlsZQ%3D%3D?line=3'>4</a> # Iterate over the entries and extract the request_id and x_request_id
#       <a href='vscode-notebook-cell:/Users/psaghelyi-remote/Project/AWS_logs/us-east-1/slow-requests.ipynb#X15sZmlsZQ%3D%3D?line=4'>5</a> for entry in data:
# ----> <a href='vscode-notebook-cell:/Users/psaghelyi-remote/Project/AWS_logs/us-east-1/slow-requests.ipynb#X15sZmlsZQ%3D%3D?line=5'>6</a>     message = entry["@message"]
#       <a href='vscode-notebook-cell:/Users/psaghelyi-remote/Project/AWS_logs/us-east-1/slow-requests.ipynb#X15sZmlsZQ%3D%3D?line=6'>7</a>     x_request_id = message.get("x_request_id", None)
#       <a href='vscode-notebook-cell:/Users/psaghelyi-remote/Project/AWS_logs/us-east-1/slow-requests.ipynb#X15sZmlsZQ%3D%3D?line=7'>8</a>     x_nginx_id = message.get("x_nginx_id", None)
#
# TypeError: list indices must be integers or slices, not str

# %%
log_group = 'projects-main'
#log_group =  'api_proxy-main'

data = []

for request_id in request_ids:
    query = f"fields @timestamp, @message \
        | filter @message like /{request_id}/ \
        | sort @timestamp desc \
        | limit 100"

    data.append(cloudwatch_query(log_group, query, start_time=days_ago(3)))

parse_messages(data)
print (json.dumps(data, indent=4))
# Out:
# Query still running...
# Query still running...
# Query still running...
# Query still running...
# Query still running...
# Query completed.
# records_scanned: 4546153
# records_matched: 0
# Query still running...
# Query still running...
# Query still running...
# Query still running...
# Query still running...
# Query completed.
# records_scanned: 4545895
# records_matched: 0
# Query still running...
# Query still running...
# Query still running...
# Query still running...
# Query completed.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/psaghelyi-remote/Project/AWS_logs/us-east-1/slow-requests.ipynb Cell 14 line 1
#       <a href='vscode-notebook-cell:/Users/psaghelyi-remote/Project/AWS_logs/us-east-1/slow-requests.ipynb#X24sZmlsZQ%3D%3D?line=5'>6</a> for request_id in request_ids:
#       <a href='vscode-notebook-cell:/Users/psaghelyi-remote/Project/AWS_logs/us-east-1/slow-requests.ipynb#X24sZmlsZQ%3D%3D?line=6'>7</a>     query = f"fields @timestamp, @message \
#       <a href='vscode-notebook-cell:/Users/psaghelyi-remote/Project/AWS_logs/us-east-1/slow-requests.ipynb#X24sZmlsZQ%3D%3D?line=7'>8</a>         | filter @message like /{request_id}/ \
#       <a href='vscode-notebook-cell:/Users/psaghelyi-remote/Project/AWS_logs/us-east-1/slow-requests.ipynb#X24sZmlsZQ%3D%3D?line=8'>9</a>         | sort @timestamp desc \
#      <a href='vscode-notebook-cell:/Users/psaghelyi-remote/Project/AWS_logs/us-east-1/slow-requests.ipynb#X24sZmlsZQ%3D%3D?line=9'>10</a>         | limit 100"
# ---> <a href='vscode-notebook-cell:/Users/psaghelyi-remote/Project/AWS_logs/us-east-1/slow-requests.ipynb#X24sZmlsZQ%3D%3D?line=11'>12</a>     data.append(cloudwatch_query(log_group, query, start_time=days_ago(3)))
#      <a href='vscode-notebook-cell:/Users/psaghelyi-remote/Project/AWS_logs/us-east-1/slow-requests.ipynb#X24sZmlsZQ%3D%3D?line=13'>14</a> parse_messages(data)
#      <a href='vscode-notebook-cell:/Users/psaghelyi-remote/Project/AWS_logs/us-east-1/slow-requests.ipynb#X24sZmlsZQ%3D%3D?line=14'>15</a> print (json.dumps(data, indent=4))
#
# /Users/psaghelyi-remote/Project/AWS_logs/us-east-1/slow-requests.ipynb Cell 14 line 3
#      <a href='vscode-notebook-cell:/Users/psaghelyi-remote/Project/AWS_logs/us-east-1/slow-requests.ipynb#X24sZmlsZQ%3D%3D?line=31'>32</a> def cloudwatch_query(log_group, query, start_time=current_timestamp(), end_time=hours_ago(1)):
#      <a href='vscode-notebook-cell:/Users/psaghelyi-remote/Project/AWS_logs/us-east-1/slow-requests.ipynb#X24sZmlsZQ%3D%3D?line=32'>33</a>     query_id = execute_query(log_group, query, start_time, end_time)
# ---> <a href='vscode-notebook-cell:/Users/psaghelyi-remote/Project/AWS_logs/us-east-1/slow-requests.ipynb#X24sZmlsZQ%3D%3D?line=33'>34</a>     wait_for_query(query_id)
#      <a href='vscode-notebook-cell:/Users/psaghelyi-remote/Project/AWS_logs/us-east-1/slow-requests.ipynb#X24sZmlsZQ%3D%3D?line=34'>35</a>     response, records_scanned, records_matched = get_query_results(query_id)
#      <a href='vscode-notebook-cell:/Users/psaghelyi-remote/Project/AWS_logs/us-east-1/slow-requests.ipynb#X24sZmlsZQ%3D%3D?line=35'>36</a>     print (f'records_scanned: {records_scanned}')
#
# /Users/psaghelyi-remote/Project/AWS_logs/us-east-1/slow-requests.ipynb Cell 14 line 2
#      <a href='vscode-notebook-cell:/Users/psaghelyi-remote/Project/AWS_logs/us-east-1/slow-requests.ipynb#X24sZmlsZQ%3D%3D?line=22'>23</a> else:
#      <a href='vscode-notebook-cell:/Users/psaghelyi-remote/Project/AWS_logs/us-east-1/slow-requests.ipynb#X24sZmlsZQ%3D%3D?line=23'>24</a>     print(f"Query status: {status}")
# ---> <a href='vscode-notebook-cell:/Users/psaghelyi-remote/Project/AWS_logs/us-east-1/slow-requests.ipynb#X24sZmlsZQ%3D%3D?line=24'>25</a> time.sleep(1)
#
# KeyboardInterrupt:
