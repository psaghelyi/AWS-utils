# %% [markdown]
# # Executing AWS CloudWatch Queries

# %%
import boto3
import subprocess
import json
import os
import time
import pandas as pd
from concurrent.futures import ThreadPoolExecutor, as_completed

import sys
sys.path.append('..')
from awsutils import *

# %% [markdown]
# ## Step 1: Create session and client

# %%
# Use the function with your profile to get a session
aws_session = set_aws_credentials('acl-production', 'eu-central-1')

# Create clients using the session
sts_client = aws_session.client('sts')
logs_client = aws_session.client('logs')

# Example usage of the clients
account_id = sts_client.get_caller_identity()["Account"]
print("Current AWS Account ID:", account_id)
# Out:
# Current AWS Account ID: 707785685172

# %% [markdown]
# ## Collect the request ids

# %%
def collect_request_ids(data):
    request_ids = []

    # Iterate over the entries and extract the request_id and x_request_id
    for entry in data:
        message = entry["@message"]
        x_request_id = message.get("x_request_id", None)
        x_nginx_id = message.get("x_nginx_id", None)

        if x_request_id or x_nginx_id:
            if x_request_id:
                request_ids.append(x_request_id)
            if x_nginx_id != x_request_id:
                request_ids.append(x_nginx_id)

    return request_ids

# %% [markdown]
# ## Collect slow queries and corresponding request ids

# %%
log_group = 'projects-main'
#log_group =  'api_proxy-main'
min_duration = 5

query = f"fields @timestamp, @message \
    | filter @logStream like 'application/nginx' \
    | filter request_time > {min_duration} \
    | sort @timestamp desc \
    | limit 100"

print (f'Querying log group: {log_group}. Looking for slow requests... (> {min_duration}s)')
data = cloudwatch_query(logs_client, log_group, query, start_time=days_ago(3))
parse_json_messages(data)
print (json.dumps(data, indent=4))
# Out:
# Querying log group: projects-main. Looking for slow requests... (> 5s)
# Query still running...
# Query still running...
# Query still running...
# Query completed.
# records_scanned: 176881464
# records_matched: 21416
# [
#     {
#         "@timestamp": "2024-01-25 09:16:33.138",
#         "@message": {
#             "time_local": "25/Jan/2024:09:16:33 +0000",
#             "client": "10.185.254.11",
#             "ACL_Cloudfront": "",
#             "method": "GET",
#             "scheme": "http",
#             "host": "projects-eu.highbond.com",
#             "request": "GET /api/v3/projects?org_id=4455&fields%5Bprojects%5D=custom_attributes%2Cattributes%2Ccollaborator_groups%2Ccollaborators%2Cname%2Cstate%2Cstatus%2Cplanned_start_date%2Cactual_start_date%2Cplanned_end_date%2Cactual_end_date%2Cplanned_milestone_date%2Cstart_date%2Ctarget_date%2Cactual_milestone_date&page%5Bsize%5D=100&page%5Bnumber%5D=MTI%3D HTTP/1.1",
#             "request_length": "4125",
#             "status": "200",
#             "bytes_sent": "141306",
#             "body_bytes_sent": "140276",
#             "referrer": "",
#             "user_agent": "RestSharp/107.3.0.0",
#             "request_time": "32.225",
#             "remote_user": "z.zohar@dhl.com",
#             "x_nginx_id": "12dd69aa66b07c627f90e8aded76b1eb",
#             "x_request_id": "84c48a92e6d83e93f2044a22c27af637",
#             "upstream_status": "200",
#             "upstream_response_time": "32.224",
#             "upstream_connect_time": "0.000",
#             "upstream_header_time": "32.224"
#         },
#         "@ptr": "CmAKHgoaNzA3Nzg1Njg1MTcyOnByb2plY3RzLW1haW4QBxI6GhgCBlhyZIMAAAAArvkcKwAGWyJsMAAAAzIgASi0v53/0zEwou2k/9MxOJ1dQPTIrwNIpKUmULTxJRgAIAEQgx8YAQ=="
#     },
#     {
#         "@timestamp": "2024-01-25 09:16:15.715",
#         "@message": {
#             "time_local": "25/Jan/2024:09:16:15 +0000",
#             "client": "10.185.255.210",
#             "ACL_Cloudfront": "",
#             "method": "GET",
#             "scheme": "http",
#             "host": "projects-eu.highbond.com",
#             "request": "GET /api/v3/my_activities?org_id=26434&meta_fields=counters%2Chigher_security&page%5Bnumber%5D=Mg%3D%3D&page%5Bsize%5D=10&sign_ckeditor_pictures=true&sort=-updated_at HTTP/1.1",
#             "request_length": "7379",
#             "status": "200",
#             "bytes_sent": "37302",
#             "body_bytes_sent": "36269",
#             "referrer": "https://schneider-electric-industries-sas.assessments-eu.highbond.com/",
#             "user_agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36",
#             "request_time": "5.003",
#             "remote_user": "anneli.nelson@se.com",
#             "x_nginx_id": "012e328eb92d48a0c2d773b4ed8e6021",
#             "x_request_id": "5653b208-f029-4484-ae3a-a02240d0d9f9",
#             "upstream_status": "200",
#             "upstream_response_time": "5.004",
#             "upstream_connect_time": "0.000",
#             "upstream_header_time": "5.004"
#         },
#         "@ptr": "CmAKHgoaNzA3Nzg1Njg1MTcyOnByb2plY3RzLW1haW4QARI6GhgCBlq5/AMAAAAACHxHvQAGWyJoUAAAAzIgASiVpJT/0zEwxfKh/9MxONV5QN/xuQRI2f8wUPbLMBgAIAEQ5lgYAQ=="
#     },
#     {
#         "@timestamp": "2024-01-25 09:15:59.104",
#         "@message": {
#             "time_local": "25/Jan/2024:09:15:59 +0000",
#             "client": "10.185.254.11",
#             "ACL_Cloudfront": "",
#             "method": "GET",
#             "scheme": "http",
#             "host": "projects-eu.highbond.com",
#             "request": "GET /api/v3/projects?org_id=4455&fields%5Bprojects%5D=custom_attributes%2Cattributes%2Ccollaborator_groups%2Ccollaborators%2Cname%2Cstate%2Cstatus%2Cplanned_start_date%2Cactual_start_date%2Cplanned_end_date%2Cactual_end_date%2Cplanned_milestone_date%2Cstart_date%2Ctarget_date%2Cactual_milestone_date&page%5Bsize%5D=100&page%5Bnumber%5D=MTE%3D HTTP/1.1",
#             "request_length": "4125",
#             "status": "200",
#             "bytes_sent": "135973",
#             "body_bytes_sent": "134943",
#             "referrer": "",
#             "user_agent": "RestSharp/107.3.0.0",
#             "request_time": "35.213",
#             "remote_user": "z.zohar@dhl.com",
#             "x_nginx_id": "d20c577d13400ce112b8f16654e5941e",
#             "x_request_id": "bbf915668e1b5188aa5821ec7116bc13",
#             "upstream_status": "200",
#             "upstream_response_time": "35.209",
#             "upstream_connect_time": "0.000",
#             "upstream_header_time": "35.209"
#         },
#         "@ptr": "CmAKHgoaNzA3Nzg1Njg1MTcyOnByb2plY3RzLW1haW4QABI6GhgCBlr5WbwAAAAACRSCOgAGWyJo0AAAAsIgASiah5b/0zEwm5Ch/9MxOMNUQM3anwNI2oUmUIfRJRgAIAEQozkYAQ=="
#     },
#     {
#         "@timestamp": "2024-01-25 09:15:57.123",
#         "@message": {
#             "time_local": "25/Jan/2024:09:15:57 +0000",
#             "client": "10.185.254.11",
#             "ACL_Cloudfront": "",
#             "method": "GET",
#             "scheme": "http",
#             "host": "projects-eu.highbond.com",
#             "request": "GET /api/v3/my_activities?org_id=26434&meta_fields=counters%2Chigher_security&page%5Bnumber%5D=MQ%3D%3D&page%5Bsize%5D=10&sign_ckeditor_pictures=true&sort=-updated_at HTTP/1.1",
#             "request_length": "7376",
#             "status": "200",
#             "bytes_sent": "38392",
#             "body_bytes_sent": "37359",
#             "referrer": "https://schneider-electric-industries-sas.assessments-eu.highbond.com/",
#             "user_agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36",
#             "request_time": "5.025",
#             "remote_user": "anneli.nelson@se.com",
#             "x_nginx_id": "ce9b736edc740be5474761eb5eeac41d",
#             "x_request_id": "844adb85-cbe1-4555-8428-0eff4dfb545d",
#             "upstream_status": "200",
#             "upstream_response_time": "5.024",
#             "upstream_connect_time": "0.000",
#             "upstream_header_time": "5.024"
#         },
#         "@ptr": "CmAKHgoaNzA3Nzg1Njg1MTcyOnByb2plY3RzLW1haW4QBhI6GhgCBlrlkzEAAAAAAt+wVgAGWyJsgAAAAhIgASjS6Z3/0zEw+Kak/9MxOItYQKyS3wJIqKEfUNH9HhgAIAEQlQQYAQ=="
#     },
#     {
#         "@timestamp": "2024-01-25 09:15:56.827",
#         "@message": {
#             "time_local": "25/Jan/2024:09:15:56 +0000",
#             "client": "10.185.254.11",
#             "ACL_Cloudfront": "",
#             "method": "GET",
#             "scheme": "http",
#             "host": "projects-eu.highbond.com",
#             "request": "GET /api/v3/my_activities?org_id=26434&filter%5Bactivity_progress%5D=open&meta_fields=counters&page%5Bnumber%5D=MQ%3D%3D&page%5Bsize%5D=10&sign_ckeditor_pictures=true&sort=-updated_at HTTP/1.1",
#             "request_length": "7402",
#             "status": "200",
#             "bytes_sent": "38390",
#             "body_bytes_sent": "37357",
#             "referrer": "https://schneider-electric-industries-sas.assessments-eu.highbond.com/",
#             "user_agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36",
#             "request_time": "6.701",
#             "remote_user": "anneli.nelson@se.com",
#             "x_nginx_id": "9ed95292b267f14652e40d92f4b30908",
#             "x_request_id": "564e7728-2461-4e52-a381-3d2f41b761e6",
#             "upstream_status": "200",
#             "upstream_response_time": "6.700",
#             "upstream_connect_time": "0.000",
#             "upstream_header_time": "6.700"
#         },
#         "@ptr": "CmAKHgoaNzA3Nzg1Njg1MTcyOnByb2plY3RzLW1haW4QBxI6GhgCBlhyZIMAAAAArvkcKwAGWyJsMAAAAzIgASi0v53/0zEwou2k/9MxOJ1dQPTIrwNIpKUmULTxJRgAIAEQqgUYAQ=="
#     },
#     {
#         "@timestamp": "2024-01-25 09:15:22.994",
#         "@message": {
#             "time_local": "25/Jan/2024:09:15:22 +0000",
#             "client": "10.185.255.210",
#             "ACL_Cloudfront": "",
#             "method": "GET",
#             "scheme": "http",
#             "host": "projects-eu.highbond.com",
#             "request": "GET /api/v3/projects?org_id=4455&fields%5Bprojects%5D=custom_attributes%2Cattributes%2Ccollaborator_groups%2Ccollaborators%2Cname%2Cstate%2Cstatus%2Cplanned_start_date%2Cactual_start_date%2Cplanned_end_date%2Cactual_end_date%2Cplanned_milestone_date%2Cstart_date%2Ctarget_date%2Cactual_milestone_date&page%5Bsize%5D=100&page%5Bnumber%5D=MTA%3D HTTP/1.1",
#             "request_length": "4125",
#             "status": "200",
#             "bytes_sent": "131399",
#             "body_bytes_sent": "130369",
#             "referrer": "",
#             "user_agent": "RestSharp/107.3.0.0",
#             "request_time": "27.821",
#             "remote_user": "z.zohar@dhl.com",
#             "x_nginx_id": "27237cb25e310264cf42bc432bece9e0",
#             "x_request_id": "4db08eb49d23b3576641fdbe4d504f40",
#             "upstream_status": "200",
#             "upstream_response_time": "27.824",
#             "upstream_connect_time": "0.004",
#             "upstream_header_time": "27.824"
#         },
#         "@ptr": "CmAKHgoaNzA3Nzg1Njg1MTcyOnByb2plY3RzLW1haW4QAxI6GhgCBlOhhOIAAAAA2z11xwAGWyJpcAAAAiIgASiU4Zn/0zEwqryi/9MxOK1eQOD6sANI4LkmUOeFJhgAIAEQjRIYAQ=="
#     },
#     {
#         "@timestamp": "2024-01-25 09:15:20.670",
#         "@message": {
#             "time_local": "25/Jan/2024:09:15:20 +0000",
#             "client": "10.185.255.210",
#             "ACL_Cloudfront": "",
#             "method": "GET",
#             "scheme": "http",
#             "host": "ardagh-group.projects-eu.highbond.com",
#             "request": "GET /project_integration/result_control_tests/1876613?projects_record_type=Walkthrough&workpage_xp=new HTTP/1.1",
#             "request_length": "4612",
#             "status": "200",
#             "bytes_sent": "2786",
#             "body_bytes_sent": "1312",
#             "referrer": "https://ardagh-group.projects-eu.highbond.com/audits/94283/objectives/385319/walkthroughs/1876613",
#             "user_agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36 Edg/120.0.0.0",
#             "request_time": "7.384",
#             "remote_user": "",
#             "x_nginx_id": "661e0a5af5f3e266fb0b45ad0ad0af47",
#             "x_request_id": "661e0a5af5f3e266fb0b45ad0ad0af47",
#             "upstream_status": "200",
#             "upstream_response_time": "7.384",
#             "upstream_connect_time": "0.004",
#             "upstream_header_time": "7.384"
#         },
#         "@ptr": "CmAKHgoaNzA3Nzg1Njg1MTcyOnByb2plY3RzLW1haW4QBBI6GhgCBlq7rBMAAAAAKUri2gAGWyJk0AAAADIgASjM25H/0zEwzIid/9MxONhgQL/R/wNInKUsUJbvKxgAIAEQg1UYAQ=="
#     },
#     {
#         "@timestamp": "2024-01-25 09:15:20.313",
#         "@message": {
#             "time_local": "25/Jan/2024:09:15:20 +0000",
#             "client": "10.185.255.210",
#             "ACL_Cloudfront": "",
#             "method": "GET",
#             "scheme": "http",
#             "host": "projects-eu.highbond.com",
#             "request": "GET /api/v3/mitigations/2245622?org_id=38645 HTTP/1.1",
#             "request_length": "3820",
#             "status": "499",
#             "bytes_sent": "0",
#             "body_bytes_sent": "0",
#             "referrer": "",
#             "user_agent": "python-requests/2.26.0",
#             "request_time": "60.000",
#             "remote_user": "podriscoll@diligent.com",
#             "x_nginx_id": "265019f5cde2199d69ad56ca749ca226",
#             "x_request_id": "a0304bc2df70d678578c3e76f5fb0853",
#             "upstream_status": "-",
#             "upstream_response_time": "60.001",
#             "upstream_connect_time": "0.000",
#             "upstream_header_time": "-"
#         },
#         "@ptr": "CmAKHgoaNzA3Nzg1Njg1MTcyOnByb2plY3RzLW1haW4QBhI6GhgCBlrlkzEAAAAAAt9fzwAGWyJmYAAAAhIgASiZ2pP/0zEwxYGe/9MxOPVeQIzXwQNIpPgnUMTDJxgAIAEQzzkYAQ=="
#     },
#     {
#         "@timestamp": "2024-01-25 09:14:53.861",
#         "@message": {
#             "time_local": "25/Jan/2024:09:14:53 +0000",
#             "client": "10.185.254.11",
#             "ACL_Cloudfront": "",
#             "method": "GET",
#             "scheme": "http",
#             "host": "projects-eu.highbond.com",
#             "request": "GET /api/v3/projects?org_id=4455&fields%5Bprojects%5D=custom_attributes%2Cattributes%2Ccollaborator_groups%2Ccollaborators%2Cname%2Cstate%2Cstatus%2Cplanned_start_date%2Cactual_start_date%2Cplanned_end_date%2Cactual_end_date%2Cplanned_milestone_date%2Cstart_date%2Ctarget_date%2Cactual_milestone_date&page%5Bsize%5D=100&page%5Bnumber%5D=OQ%3D%3D HTTP/1.1",
#             "request_length": "4127",
#             "status": "200",
#             "bytes_sent": "127365",
#             "body_bytes_sent": "126335",
#             "referrer": "",
#             "user_agent": "RestSharp/107.3.0.0",
#             "request_time": "36.237",
#             "remote_user": "z.zohar@dhl.com",
#             "x_nginx_id": "ff3c7d77f89eb8182482d3611312654f",
#             "x_request_id": "f354296a07447bd2cdd8eebac71339ea",
#             "upstream_status": "200",
#             "upstream_response_time": "36.240",
#             "upstream_connect_time": "0.004",
#             "upstream_header_time": "36.240"
#         },
#         "@ptr": "CmAKHgoaNzA3Nzg1Njg1MTcyOnByb2plY3RzLW1haW4QAxI6GhgCBlOhhOIAAAAA2zx8ygAGWyJh4AAAAiIgASibi4//0zEwv4Kb/9MxOIByQMCS1ARInJ4yULToMRgAIAEQ0mgYAQ=="
#     },
#     {
#         "@timestamp": "2024-01-25 09:14:49.619",
#         "@message": {
#             "time_local": "25/Jan/2024:09:14:49 +0000",
#             "client": "10.185.254.11",
#             "ACL_Cloudfront": "",
#             "method": "GET",
#             "scheme": "http",
#             "host": "projects-eu.highbond.com",
#             "request": "GET /api/v3/mitigations/2501733?org_id=38333 HTTP/1.1",
#             "request_length": "3816",
#             "status": "499",
#             "bytes_sent": "0",
#             "body_bytes_sent": "0",
#             "referrer": "",
#             "user_agent": "python-requests/2.26.0",
#             "request_time": "60.002",
#             "remote_user": "akrommer@diligent.com",
#             "x_nginx_id": "01c55213602dd8d8e6392e15988a8720",
#             "x_request_id": "f985aae369914ad900950f5f8abc22d1",
#             "upstream_status": "-",
#             "upstream_response_time": "60.000",
#             "upstream_connect_time": "0.000",
#             "upstream_header_time": "-"
#         },
#         "@ptr": "CmAKHgoaNzA3Nzg1Njg1MTcyOnByb2plY3RzLW1haW4QBxI6GhgCBlhyZIMAAAAArvc59gAGWyJlQAAAAzIgASisoJT/0zEw0t+d/9MxOIptQJa9rwRI+a0uUND4LRgAIAEQjzQYAQ=="
#     },
#     {
#         "@timestamp": "2024-01-25 09:14:25.045",
#         "@message": {
#             "time_local": "25/Jan/2024:09:14:25 +0000",
#             "client": "10.185.254.11",
#             "ACL_Cloudfront": "",
#             "method": "GET",
#             "scheme": "http",
#             "host": "deutsche-post-ag.projects-eu.highbond.com",
#             "request": "GET /audits/84795/dashboard?activity_logs_pagination=true HTTP/1.1",
#             "request_length": "4858",
#             "status": "200",
#             "bytes_sent": "2487",
#             "body_bytes_sent": "1013",
#             "referrer": "https://deutsche-post-ag.projects-eu.highbond.com/audits/84795/dashboard",
#             "user_agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36",
#             "request_time": "5.610",
#             "remote_user": "",
#             "x_nginx_id": "e73b2e397230820aee750c825e9b098f",
#             "x_request_id": "e73b2e397230820aee750c825e9b098f",
#             "upstream_status": "200",
#             "upstream_response_time": "5.612",
#             "upstream_connect_time": "0.004",
#             "upstream_header_time": "5.612"
#         },
#         "@ptr": "CmAKHgoaNzA3Nzg1Njg1MTcyOnByb2plY3RzLW1haW4QAxI6GhgCBlOhhOIAAAAA2zx8ygAGWyJh4AAAAiIgASibi4//0zEwv4Kb/9MxOIByQMCS1ARInJ4yULToMRgAIAEQ7FMYAQ=="
#     },
#     {
#         "@timestamp": "2024-01-25 09:14:17.404",
#         "@message": {
#             "time_local": "25/Jan/2024:09:14:17 +0000",
#             "client": "10.185.255.210",
#             "ACL_Cloudfront": "",
#             "method": "GET",
#             "scheme": "http",
#             "host": "projects-eu.highbond.com",
#             "request": "GET /api/v3/projects?org_id=4455&fields%5Bprojects%5D=custom_attributes%2Cattributes%2Ccollaborator_groups%2Ccollaborators%2Cname%2Cstate%2Cstatus%2Cplanned_start_date%2Cactual_start_date%2Cplanned_end_date%2Cactual_end_date%2Cplanned_milestone_date%2Cstart_date%2Ctarget_date%2Cactual_milestone_date&page%5Bsize%5D=100&page%5Bnumber%5D=OA%3D%3D HTTP/1.1",
#             "request_length": "4127",
#             "status": "200",
#             "bytes_sent": "132322",
#             "body_bytes_sent": "131292",
#             "referrer": "",
#             "user_agent": "RestSharp/107.3.0.0",
#             "request_time": "26.901",
#             "remote_user": "z.zohar@dhl.com",
#             "x_nginx_id": "3f226e3fc9914f37ed2798ea603071e0",
#             "x_request_id": "99cd5546c6ce295226bb8f7598ffb1d1",
#             "upstream_status": "200",
#             "upstream_response_time": "26.904",
#             "upstream_connect_time": "0.004",
#             "upstream_header_time": "26.904"
#         },
#         "@ptr": "CmAKHgoaNzA3Nzg1Njg1MTcyOnByb2plY3RzLW1haW4QBxI6GhgCBlhyZIMAAAAArvc59gAGWyJlQAAAAzIgASisoJT/0zEw0t+d/9MxOIptQJa9rwRI+a0uUND4LRgAIAEQxxEYAQ=="
#     },
#     {
#         "@timestamp": "2024-01-25 09:14:13.234",
#         "@message": {
#             "time_local": "25/Jan/2024:09:14:13 +0000",
#             "client": "10.185.255.210",
#             "ACL_Cloudfront": "",
#             "method": "GET",
#             "scheme": "http",
#             "host": "projects-eu.highbond.com",
#             "request": "GET /api/v3/my_activities?org_id=26434&meta_fields=counters%2Chigher_security&page%5Bnumber%5D=MQ%3D%3D&page%5Bsize%5D=10&sign_ckeditor_pictures=true&sort=-updated_at HTTP/1.1",
#             "request_length": "7376",
#             "status": "200",
#             "bytes_sent": "38392",
#             "body_bytes_sent": "37359",
#             "referrer": "https://schneider-electric-industries-sas.assessments-eu.highbond.com/",
#             "user_agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36",
#             "request_time": "5.001",
#             "remote_user": "anneli.nelson@se.com",
#             "x_nginx_id": "0fe88e608f82ed117baa86d2ba53a3fc",
#             "x_request_id": "58e8922c-b90e-43c1-80e1-fa596c43ba9a",
#             "upstream_status": "200",
#             "upstream_response_time": "4.996",
#             "upstream_connect_time": "0.000",
#             "upstream_header_time": "4.996"
#         },
#         "@ptr": "CmAKHgoaNzA3Nzg1Njg1MTcyOnByb2plY3RzLW1haW4QBBI6GhgCBlq7rBMAAAAAKUri2gAGWyJk0AAAADIgASjM25H/0zEwzIid/9MxONhgQL/R/wNInKUsUJbvKxgAIAEQoRgYAQ=="
#     },
#     {
#         "@timestamp": "2024-01-25 09:14:10.574",
#         "@message": {
#             "time_local": "25/Jan/2024:09:14:10 +0000",
#             "client": "10.185.255.210",
#             "ACL_Cloudfront": "",
#             "method": "GET",
#             "scheme": "http",
#             "host": "projects-eu.highbond.com",
#             "request": "GET /api/v3/my_activities?org_id=26434&filter%5Bactivity_progress%5D=open&meta_fields=counters&page%5Bnumber%5D=MQ%3D%3D&page%5Bsize%5D=10&sign_ckeditor_pictures=true&sort=-updated_at HTTP/1.1",
#             "request_length": "7401",
#             "status": "200",
#             "bytes_sent": "38390",
#             "body_bytes_sent": "37357",
#             "referrer": "https://schneider-electric-industries-sas.assessments-eu.highbond.com/",
#             "user_agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36",
#             "request_time": "5.482",
#             "remote_user": "anneli.nelson@se.com",
#             "x_nginx_id": "b44d4cbaa618dd53d45db00bb2624648",
#             "x_request_id": "3d4d6caa-4943-4b13-b821-e882c34078d9",
#             "upstream_status": "200",
#             "upstream_response_time": "5.487",
#             "upstream_connect_time": "0.004",
#             "upstream_header_time": "5.487"
#         },
#         "@ptr": "CmAKHgoaNzA3Nzg1Njg1MTcyOnByb2plY3RzLW1haW4QBBI6GhgCBlq7rBMAAAAAKUri2gAGWyJk0AAAADIgASjM25H/0zEwzIid/9MxONhgQL/R/wNInKUsUJbvKxgAIAEQwxcYAQ=="
#     },
#     {
#         "@timestamp": "2024-01-25 09:13:49.927",
#         "@message": {
#             "time_local": "25/Jan/2024:09:13:49 +0000",
#             "client": "10.185.255.210",
#             "ACL_Cloudfront": "",
#             "method": "GET",
#             "scheme": "http",
#             "host": "projects-eu.highbond.com",
#             "request": "GET /api/v3/projects?org_id=4455&fields%5Bprojects%5D=custom_attributes%2Cattributes%2Ccollaborator_groups%2Ccollaborators%2Cname%2Cstate%2Cstatus%2Cplanned_start_date%2Cactual_start_date%2Cplanned_end_date%2Cactual_end_date%2Cplanned_milestone_date%2Cstart_date%2Ctarget_date%2Cactual_milestone_date&page%5Bsize%5D=100&page%5Bnumber%5D=Nw%3D%3D HTTP/1.1",
#             "request_length": "4127",
#             "status": "200",
#             "bytes_sent": "130387",
#             "body_bytes_sent": "129357",
#             "referrer": "",
#             "user_agent": "RestSharp/107.3.0.0",
#             "request_time": "31.282",
#             "remote_user": "z.zohar@dhl.com",
#             "x_nginx_id": "8af9e66f1bfb104142f911bf8b3cbafa",
#             "x_request_id": "3624e0eeac9bcdc3e15e4b6267ffec67",
#             "upstream_status": "200",
#             "upstream_response_time": "31.279",
#             "upstream_connect_time": "0.000",
#             "upstream_header_time": "31.279"
#         },
#         "@ptr": "CmAKHgoaNzA3Nzg1Njg1MTcyOnByb2plY3RzLW1haW4QAhI6GhgCBlisQSoAAAAAjVIvrQAGWyJfMAAAAqIgASiE4pD/0zEw2IWY/9MxOItmQMOhoQRI/6ouUKj1LRgAIAEQtFAYAQ=="
#     },
#     {
#         "@timestamp": "2024-01-25 09:13:18.225",
#         "@message": {
#             "time_local": "25/Jan/2024:09:13:18 +0000",
#             "client": "10.185.254.11",
#             "ACL_Cloudfront": "",
#             "method": "GET",
#             "scheme": "http",
#             "host": "projects-eu.highbond.com",
#             "request": "GET /api/v3/projects?org_id=4455&fields%5Bprojects%5D=custom_attributes%2Cattributes%2Ccollaborator_groups%2Ccollaborators%2Cname%2Cstate%2Cstatus%2Cplanned_start_date%2Cactual_start_date%2Cplanned_end_date%2Cactual_end_date%2Cplanned_milestone_date%2Cstart_date%2Ctarget_date%2Cactual_milestone_date&page%5Bsize%5D=100&page%5Bnumber%5D=Ng%3D%3D HTTP/1.1",
#             "request_length": "4126",
#             "status": "200",
#             "bytes_sent": "130021",
#             "body_bytes_sent": "128991",
#             "referrer": "",
#             "user_agent": "RestSharp/107.3.0.0",
#             "request_time": "29.624",
#             "remote_user": "z.zohar@dhl.com",
#             "x_nginx_id": "706dc8f2fd075997d81893b2726967b9",
#             "x_request_id": "365ad11f0c9c969e0b1e18386f63c4e1",
#             "upstream_status": "200",
#             "upstream_response_time": "29.621",
#             "upstream_connect_time": "0.000",
#             "upstream_header_time": "29.621"
#         },
#         "@ptr": "CmAKHgoaNzA3Nzg1Njg1MTcyOnByb2plY3RzLW1haW4QARI6GhgCBlq5/AMAAAAACHuKmgAGWyJggAAAAzIgASjRiZL/0zEwxPOZ/9MxONdyQMn22QRInOozULW0MxgAIAEQ4icYAQ=="
#     },
#     {
#         "@timestamp": "2024-01-25 09:12:47.947",
#         "@message": {
#             "time_local": "25/Jan/2024:09:12:47 +0000",
#             "client": "10.185.254.11",
#             "ACL_Cloudfront": "",
#             "method": "GET",
#             "scheme": "http",
#             "host": "projects-eu.highbond.com",
#             "request": "GET /api/v3/projects?org_id=4455&fields%5Bprojects%5D=custom_attributes%2Cattributes%2Ccollaborator_groups%2Ccollaborators%2Cname%2Cstate%2Cstatus%2Cplanned_start_date%2Cactual_start_date%2Cplanned_end_date%2Cactual_end_date%2Cplanned_milestone_date%2Cstart_date%2Ctarget_date%2Cactual_milestone_date&page%5Bsize%5D=100&page%5Bnumber%5D=NQ%3D%3D HTTP/1.1",
#             "request_length": "4127",
#             "status": "200",
#             "bytes_sent": "125565",
#             "body_bytes_sent": "124535",
#             "referrer": "",
#             "user_agent": "RestSharp/107.3.0.0",
#             "request_time": "28.212",
#             "remote_user": "z.zohar@dhl.com",
#             "x_nginx_id": "9d1a84a05834cd74b02038277dcc0bc1",
#             "x_request_id": "eff5a09f9efa55e2e1fe1f70cf7047b5",
#             "upstream_status": "200",
#             "upstream_response_time": "28.212",
#             "upstream_connect_time": "0.000",
#             "upstream_header_time": "28.212"
#         },
#         "@ptr": "CmAKHgoaNzA3Nzg1Njg1MTcyOnByb2plY3RzLW1haW4QAhI6GhgCBlisQSoAAAAAjVIvrQAGWyJfMAAAAqIgASiE4pD/0zEw2IWY/9MxOItmQMOhoQRI/6ouUKj1LRgAIAEQ0h4YAQ=="
#     },
#     {
#         "@timestamp": "2024-01-25 09:12:36.037",
#         "@message": {
#             "time_local": "25/Jan/2024:09:12:36 +0000",
#             "client": "10.185.255.210",
#             "ACL_Cloudfront": "",
#             "method": "GET",
#             "scheme": "http",
#             "host": "projects-eu.highbond.com",
#             "request": "GET /api/v3/my_activities?org_id=26434&meta_fields=counters%2Chigher_security&page%5Bnumber%5D=MQ%3D%3D&page%5Bsize%5D=10&sign_ckeditor_pictures=true&sort=-updated_at HTTP/1.1",
#             "request_length": "7373",
#             "status": "200",
#             "bytes_sent": "38392",
#             "body_bytes_sent": "37359",
#             "referrer": "https://schneider-electric-industries-sas.assessments-eu.highbond.com/",
#             "user_agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36",
#             "request_time": "5.130",
#             "remote_user": "anneli.nelson@se.com",
#             "x_nginx_id": "d7c6acc70482a982aad6fd0adb8d98a7",
#             "x_request_id": "8df7346e-2c76-4a70-89de-44c0c7f9d099",
#             "upstream_status": "200",
#             "upstream_response_time": "5.128",
#             "upstream_connect_time": "0.000",
#             "upstream_header_time": "5.128"
#         },
#         "@ptr": "CmAKHgoaNzA3Nzg1Njg1MTcyOnByb2plY3RzLW1haW4QBRI6GhgCBlr4jLgAAAAAD1n/7gAGWyJfkAAAAIIgASjSmZH/0zEwrPWX/9MxONFWQLy5rANIx6smUM32JRgAIAEQjAcYAQ=="
#     },
#     {
#         "@timestamp": "2024-01-25 09:12:31.775",
#         "@message": {
#             "time_local": "25/Jan/2024:09:12:31 +0000",
#             "client": "10.185.254.11",
#             "ACL_Cloudfront": "",
#             "method": "GET",
#             "scheme": "http",
#             "host": "projects-eu.highbond.com",
#             "request": "GET /api/v3/my_activities?org_id=26434&filter%5Bactivity_progress%5D=open&meta_fields=counters&page%5Bnumber%5D=MQ%3D%3D&page%5Bsize%5D=10&sign_ckeditor_pictures=true&sort=-updated_at HTTP/1.1",
#             "request_length": "7392",
#             "status": "200",
#             "bytes_sent": "38383",
#             "body_bytes_sent": "37350",
#             "referrer": "https://schneider-electric-industries-sas.assessments-eu.highbond.com/",
#             "user_agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36",
#             "request_time": "5.457",
#             "remote_user": "anneli.nelson@se.com",
#             "x_nginx_id": "32ca8f169518efcc74121a9d7fbcaf44",
#             "x_request_id": "6687dd2a-31e5-41ef-a3d0-ff7255c4ea2f",
#             "upstream_status": "200",
#             "upstream_response_time": "5.452",
#             "upstream_connect_time": "0.000",
#             "upstream_header_time": "5.452"
#         },
#         "@ptr": "CmAKHgoaNzA3Nzg1Njg1MTcyOnByb2plY3RzLW1haW4QABI6GhgCBlr5WbwAAAAACQ86IwAGWyJbIAAAAsIgASj55oj/0zEwq8OT/9MxOINVQLbpvANI7+cnUJqxJxgAIAEQ0DwYAQ=="
#     },
#     {
#         "@timestamp": "2024-01-25 09:12:29.192",
#         "@message": {
#             "time_local": "25/Jan/2024:09:12:29 +0000",
#             "client": "10.185.254.11",
#             "ACL_Cloudfront": "",
#             "method": "GET",
#             "scheme": "http",
#             "host": "tatamotorsgroup-production.projects-eu.highbond.com",
#             "request": "GET /audits/95639/assessments/assessment_items?assessable_id=1928462&assessable_type=Walkthrough HTTP/1.1",
#             "request_length": "3745",
#             "status": "200",
#             "bytes_sent": "1808",
#             "body_bytes_sent": "327",
#             "referrer": "https://tatamotorsgroup-production.projects-eu.highbond.com/audits/95639/objectives/395128/walkthroughs/1928462",
#             "user_agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36",
#             "request_time": "5.139",
#             "remote_user": "",
#             "x_nginx_id": "424cbdbde20f31de18367c60db5ab420",
#             "x_request_id": "424cbdbde20f31de18367c60db5ab420",
#             "upstream_status": "200",
#             "upstream_response_time": "5.140",
#             "upstream_connect_time": "0.004",
#             "upstream_header_time": "5.140"
#         },
#         "@ptr": "CmAKHgoaNzA3Nzg1Njg1MTcyOnByb2plY3RzLW1haW4QBRI6GhgCBlr4jLgAAAAAD1n/7gAGWyJfkAAAAIIgASjSmZH/0zEwrPWX/9MxONFWQLy5rANIx6smUM32JRgAIAEQlwQYAQ=="
#     },
#     {
#         "@timestamp": "2024-01-25 09:12:19.275",
#         "@message": {
#             "time_local": "25/Jan/2024:09:12:19 +0000",
#             "client": "10.185.255.210",
#             "ACL_Cloudfront": "",
#             "method": "GET",
#             "scheme": "http",
#             "host": "projects-eu.highbond.com",
#             "request": "GET /api/v3/projects?org_id=4455&fields%5Bprojects%5D=custom_attributes%2Cattributes%2Ccollaborator_groups%2Ccollaborators%2Cname%2Cstate%2Cstatus%2Cplanned_start_date%2Cactual_start_date%2Cplanned_end_date%2Cactual_end_date%2Cplanned_milestone_date%2Cstart_date%2Ctarget_date%2Cactual_milestone_date&page%5Bsize%5D=100&page%5Bnumber%5D=NA%3D%3D HTTP/1.1",
#             "request_length": "4127",
#             "status": "200",
#             "bytes_sent": "134282",
#             "body_bytes_sent": "133252",
#             "referrer": "",
#             "user_agent": "RestSharp/107.3.0.0",
#             "request_time": "35.005",
#             "remote_user": "z.zohar@dhl.com",
#             "x_nginx_id": "cbd6c42c84ffca3dd683f2e5c9430e6a",
#             "x_request_id": "43dca55eae2c65a0e5cc000eb7b5f4e6",
#             "upstream_status": "200",
#             "upstream_response_time": "35.008",
#             "upstream_connect_time": "0.004",
#             "upstream_header_time": "35.008"
#         },
#         "@ptr": "CmAKHgoaNzA3Nzg1Njg1MTcyOnByb2plY3RzLW1haW4QAxI6GhgCBlOhhOIAAAAA2zuX3QAGWyJasAAAAiIgASjj+4f/0zEw7MyT/9MxONlmQIPKmgRIs8IuUKCMLhgAIAEQpD0YAQ=="
#     },
#     {
#         "@timestamp": "2024-01-25 09:11:44.028",
#         "@message": {
#             "time_local": "25/Jan/2024:09:11:44 +0000",
#             "client": "10.185.254.11",
#             "ACL_Cloudfront": "",
#             "method": "GET",
#             "scheme": "http",
#             "host": "projects-eu.highbond.com",
#             "request": "GET /api/v3/projects?org_id=4455&fields%5Bprojects%5D=custom_attributes%2Cattributes%2Ccollaborator_groups%2Ccollaborators%2Cname%2Cstate%2Cstatus%2Cplanned_start_date%2Cactual_start_date%2Cplanned_end_date%2Cactual_end_date%2Cplanned_milestone_date%2Cstart_date%2Ctarget_date%2Cactual_milestone_date&page%5Bsize%5D=100&page%5Bnumber%5D=Mw%3D%3D HTTP/1.1",
#             "request_length": "4127",
#             "status": "200",
#             "bytes_sent": "136287",
#             "body_bytes_sent": "135257",
#             "referrer": "",
#             "user_agent": "RestSharp/107.3.0.0",
#             "request_time": "28.872",
#             "remote_user": "z.zohar@dhl.com",
#             "x_nginx_id": "25f33a66a737ce1c645219ab855dc5ea",
#             "x_request_id": "08504742a59ba7372d78b1573b22c921",
#             "upstream_status": "200",
#             "upstream_response_time": "28.872",
#             "upstream_connect_time": "0.000",
#             "upstream_header_time": "28.872"
#         },
#         "@ptr": "CmAKHgoaNzA3Nzg1Njg1MTcyOnByb2plY3RzLW1haW4QBBI6GhgCBlq7rBMAAAAAKUe5XgAGWyJXwAAAADIgASioyYn/0zEwtYyQ/9MxOLlWQLHRtgNIzMUnUNWPJxgAIAEQnEUYAQ=="
#     },
#     {
#         "@timestamp": "2024-01-25 09:11:14.922",
#         "@message": {
#             "time_local": "25/Jan/2024:09:11:14 +0000",
#             "client": "10.185.254.11",
#             "ACL_Cloudfront": "",
#             "method": "GET",
#             "scheme": "http",
#             "host": "projects-eu.highbond.com",
#             "request": "GET /api/v3/projects?org_id=4455&fields%5Bprojects%5D=custom_attributes%2Cattributes%2Ccollaborator_groups%2Ccollaborators%2Cname%2Cstate%2Cstatus%2Cplanned_start_date%2Cactual_start_date%2Cplanned_end_date%2Cactual_end_date%2Cplanned_milestone_date%2Cstart_date%2Ctarget_date%2Cactual_milestone_date&page%5Bsize%5D=100&page%5Bnumber%5D=Mg%3D%3D HTTP/1.1",
#             "request_length": "4126",
#             "status": "200",
#             "bytes_sent": "138109",
#             "body_bytes_sent": "137079",
#             "referrer": "",
#             "user_agent": "RestSharp/107.3.0.0",
#             "request_time": "36.021",
#             "remote_user": "z.zohar@dhl.com",
#             "x_nginx_id": "7576b8f94e0668896c1a5f05f68b0fe0",
#             "x_request_id": "2a15eac06ef2fbf6344660f3123ab840",
#             "upstream_status": "200",
#             "upstream_response_time": "36.020",
#             "upstream_connect_time": "0.004",
#             "upstream_header_time": "36.020"
#         },
#         "@ptr": "CmAKHgoaNzA3Nzg1Njg1MTcyOnByb2plY3RzLW1haW4QAhI6GhgCBlisQSoAAAAAjVChAwAGWyJYAAAAAqIgASjQ34n/0zEwqoKR/9MxOK9nQNjAlwRI9e0uUJa4LhgAIAEQ1TcYAQ=="
#     },
#     {
#         "@timestamp": "2024-01-25 09:11:04.751",
#         "@message": {
#             "time_local": "25/Jan/2024:09:11:04 +0000",
#             "client": "10.185.255.210",
#             "ACL_Cloudfront": "",
#             "method": "GET",
#             "scheme": "http",
#             "host": "ardagh-group.projects-eu.highbond.com",
#             "request": "GET /project_integration/result_control_tests/1876675?projects_record_type=Walkthrough&workpage_xp=new HTTP/1.1",
#             "request_length": "4497",
#             "status": "200",
#             "bytes_sent": "2786",
#             "body_bytes_sent": "1312",
#             "referrer": "https://ardagh-group.projects-eu.highbond.com/audits/94283/objectives/385319/walkthroughs/1876675",
#             "user_agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36 Edg/120.0.0.0",
#             "request_time": "6.499",
#             "remote_user": "",
#             "x_nginx_id": "914284237aa54b903d59515fc70adeab",
#             "x_request_id": "914284237aa54b903d59515fc70adeab",
#             "upstream_status": "200",
#             "upstream_response_time": "6.496",
#             "upstream_connect_time": "0.000",
#             "upstream_header_time": "6.496"
#         },
#         "@ptr": "CmAKHgoaNzA3Nzg1Njg1MTcyOnByb2plY3RzLW1haW4QAhI6GhgCBlisQSoAAAAAjVChAwAGWyJYAAAAAqIgASjQ34n/0zEwqoKR/9MxOK9nQNjAlwRI9e0uUJa4LhgAIAEQuywYAQ=="
#     },
#     {
#         "@timestamp": "2024-01-25 09:10:37.320",
#         "@message": {
#             "time_local": "25/Jan/2024:09:10:37 +0000",
#             "client": "10.185.254.11",
#             "ACL_Cloudfront": "",
#             "method": "GET",
#             "scheme": "http",
#             "host": "projects-eu.highbond.com",
#             "request": "GET /api/v3/projects?org_id=4455&fields%5Bprojects%5D=custom_attributes%2Cattributes%2Ccollaborator_groups%2Ccollaborators%2Cname%2Cstate%2Cstatus%2Cplanned_start_date%2Cactual_start_date%2Cplanned_end_date%2Cactual_end_date%2Cplanned_milestone_date%2Cstart_date%2Ctarget_date%2Cactual_milestone_date&page%5Bsize%5D=100&page%5Bnumber%5D=MQ%3D%3D HTTP/1.1",
#             "request_length": "3766",
#             "status": "200",
#             "bytes_sent": "142368",
#             "body_bytes_sent": "141194",
#             "referrer": "",
#             "user_agent": "RestSharp/107.3.0.0",
#             "request_time": "36.457",
#             "remote_user": "z.zohar@dhl.com",
#             "x_nginx_id": "a691070f90967106425f78371dbdd1db",
#             "x_request_id": "2d7d9ada860a57769f10d719ce2c5491",
#             "upstream_status": "200",
#             "upstream_response_time": "36.457",
#             "upstream_connect_time": "0.000",
#             "upstream_header_time": "36.457"
#         },
#         "@ptr": "CmAKHgoaNzA3Nzg1Njg1MTcyOnByb2plY3RzLW1haW4QABI6GhgCBlr5WbwAAAAACQxpogAGWyJT8AAAAsIgASia7oX/0zEw/IeN/9MxONhtQLGjqQRInKswUOP0LxgAIAEQjE4YAQ=="
#     },
#     {
#         "@timestamp": "2024-01-25 09:10:14.151",
#         "@message": {
#             "time_local": "25/Jan/2024:09:10:14 +0000",
#             "client": "10.185.254.11",
#             "ACL_Cloudfront": "",
#             "method": "GET",
#             "scheme": "http",
#             "host": "projects-eu.highbond.com",
#             "request": "GET /api/v3/my_activities?org_id=26434&meta_fields=counters%2Chigher_security&page%5Bnumber%5D=MQ%3D%3D&page%5Bsize%5D=10&sign_ckeditor_pictures=true&sort=-updated_at HTTP/1.1",
#             "request_length": "7384",
#             "status": "200",
#             "bytes_sent": "38392",
#             "body_bytes_sent": "37359",
#             "referrer": "https://schneider-electric-industries-sas.assessments-eu.highbond.com/",
#             "user_agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36",
#             "request_time": "5.033",
#             "remote_user": "anneli.nelson@se.com",
#             "x_nginx_id": "e8adaa3129e1cac18c544f523b5a4536",
#             "x_request_id": "f33f1652-5aa9-4c82-8894-9693ff06aa78",
#             "upstream_status": "200",
#             "upstream_response_time": "5.036",
#             "upstream_connect_time": "0.004",
#             "upstream_header_time": "5.032"
#         },
#         "@ptr": "CmAKHgoaNzA3Nzg1Njg1MTcyOnByb2plY3RzLW1haW4QBBI6GhgCBlq7rBMAAAAAKUXGQAAGWyJQ4AAAADIgASjI4IL/0zEw7tyJ/9MxOLpfQM/42ANIguAnUIKrJxgAIAEQ/lsYAQ=="
#     },
#     {
#         "@timestamp": "2024-01-25 09:10:11.217",
#         "@message": {
#             "time_local": "25/Jan/2024:09:10:11 +0000",
#             "client": "10.185.255.210",
#             "ACL_Cloudfront": "",
#             "method": "GET",
#             "scheme": "http",
#             "host": "projects-eu.highbond.com",
#             "request": "GET /api/v3/my_activities?org_id=26434&filter%5Bactivity_progress%5D=open&meta_fields=counters&page%5Bnumber%5D=MQ%3D%3D&page%5Bsize%5D=10&sign_ckeditor_pictures=true&sort=-updated_at HTTP/1.1",
#             "request_length": "7401",
#             "status": "200",
#             "bytes_sent": "38390",
#             "body_bytes_sent": "37357",
#             "referrer": "https://schneider-electric-industries-sas.assessments-eu.highbond.com/",
#             "user_agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36",
#             "request_time": "6.801",
#             "remote_user": "anneli.nelson@se.com",
#             "x_nginx_id": "8a36d2cfe1296ec701195d96d3a51823",
#             "x_request_id": "71d71802-5449-42fc-9977-fbb2b936543b",
#             "upstream_status": "200",
#             "upstream_response_time": "6.800",
#             "upstream_connect_time": "0.000",
#             "upstream_header_time": "6.796"
#         },
#         "@ptr": "CmAKHgoaNzA3Nzg1Njg1MTcyOnByb2plY3RzLW1haW4QBhI6GhgCBlrlkzEAAAAAAt5kGgAGWyJS4AAAAhIgASjw3YT/0zEwjI+L/9MxOIZWQM/EvwNIrMEoULSLKBgAIAEQjTwYAQ=="
#     },
#     {
#         "@timestamp": "2024-01-25 09:08:35.805",
#         "@message": {
#             "time_local": "25/Jan/2024:09:08:35 +0000",
#             "client": "10.185.255.210",
#             "ACL_Cloudfront": "",
#             "method": "GET",
#             "scheme": "http",
#             "host": "ghanaportsandharbourauthority.projects-eu.highbond.com",
#             "request": "GET /dashboard/audits?fields%5Baudit%5D=name%2Cstart_date%2Ctarget_date%2Cstatus%2Cprogress%2Cfavorite&filter%5Btag%5D%5Bname%5D=TP%20Special%20Duties%20Fourth%20Quarter%202023&filter%5Btag%5D%5Buntagged%5D=false&filter%5Bquery%5D=&filter%5Bstatus%5D%5B%5D=active&sort=null HTTP/1.1",
#             "request_length": "4882",
#             "status": "499",
#             "bytes_sent": "0",
#             "body_bytes_sent": "0",
#             "referrer": "https://ghanaportsandharbourauthority.projects-eu.highbond.com/?filter%5Btag%5D%5Bname%5D=TP%20Special%20Duties%20Fourth%20Quarter%202023&filter%5Bstatus%5D%5B%5D=active",
#             "user_agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36 Edg/120.0.0.0",
#             "request_time": "52.168",
#             "remote_user": "",
#             "x_nginx_id": "c975be2d165a804460452370dc66702a",
#             "x_request_id": "c975be2d165a804460452370dc66702a",
#             "upstream_status": "-",
#             "upstream_response_time": "52.169",
#             "upstream_connect_time": "0.000",
#             "upstream_header_time": "-"
#         },
#         "@ptr": "CmAKHgoaNzA3Nzg1Njg1MTcyOnByb2plY3RzLW1haW4QBxI6GhgCBlhyZIMAAAAArvKLsgAGWyJRIAAAAzIgASjAh4P/0zEw4IyK/9MxOKBoQLDtjwRI4pYsUNnhKxgAIAEQ4wIYAQ=="
#     },
#     {
#         "@timestamp": "2024-01-25 09:08:08.900",
#         "@message": {
#             "time_local": "25/Jan/2024:09:08:08 +0000",
#             "client": "10.185.254.11",
#             "ACL_Cloudfront": "",
#             "method": "GET",
#             "scheme": "http",
#             "host": "absa-auditbond.projects-eu.highbond.com",
#             "request": "GET /audits/56024/findings HTTP/1.1",
#             "request_length": "3549",
#             "status": "200",
#             "bytes_sent": "158005",
#             "body_bytes_sent": "156545",
#             "referrer": "https://login.microsoftonline.com/",
#             "user_agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36",
#             "request_time": "7.776",
#             "remote_user": "",
#             "x_nginx_id": "1226f5e55437afb36024c63d95c9fd97",
#             "x_request_id": "1226f5e55437afb36024c63d95c9fd97",
#             "upstream_status": "200",
#             "upstream_response_time": "7.776",
#             "upstream_connect_time": "0.004",
#             "upstream_header_time": "7.764"
#         },
#         "@ptr": "CmAKHgoaNzA3Nzg1Njg1MTcyOnByb2plY3RzLW1haW4QAxI6GhgCBlOhhOIAAAAA2zlyagAGWyJKUAAAAiIgASimu/z+0zEwjoCF/9MxOMxcQJvywwNIo/AoULa7KBgAIAEQny4YAQ=="
#     },
#     {
#         "@timestamp": "2024-01-25 09:08:00.658",
#         "@message": {
#             "time_local": "25/Jan/2024:09:08:00 +0000",
#             "client": "10.185.255.210",
#             "ACL_Cloudfront": "",
#             "method": "GET",
#             "scheme": "http",
#             "host": "telepass-spa.projects-eu.highbond.com",
#             "request": "GET /assurance_plans/mitigated_strategic_risks?filter[audit_type_id]=37906 HTTP/1.1",
#             "request_length": "4678",
#             "status": "200",
#             "bytes_sent": "3835",
#             "body_bytes_sent": "2354",
#             "referrer": "https://telepass-spa.projects-eu.highbond.com/assurance_plans/1422",
#             "user_agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36",
#             "request_time": "5.371",
#             "remote_user": "",
#             "x_nginx_id": "31c88c82070d7c4f4c3c04ed88778e82",
#             "x_request_id": "31c88c82070d7c4f4c3c04ed88778e82",
#             "upstream_status": "200",
#             "upstream_response_time": "5.372",
#             "upstream_connect_time": "0.004",
#             "upstream_header_time": "5.372"
#         },
#         "@ptr": "CmAKHgoaNzA3Nzg1Njg1MTcyOnByb2plY3RzLW1haW4QBBI6GhgCBlq7rBMAAAAAKUQazQAGWyJJsAAAADIgASiX6/v+0zEwvf2C/9MxOK5JQPuH4gJI07MfUM+DHxgAIAEQwDgYAQ=="
#     },
#     {
#         "@timestamp": "2024-01-25 09:07:52.536",
#         "@message": {
#             "time_local": "25/Jan/2024:09:07:52 +0000",
#             "client": "10.185.254.11",
#             "ACL_Cloudfront": "",
#             "method": "GET",
#             "scheme": "http",
#             "host": "atlas-copco-ab.projects-eu.highbond.com",
#             "request": "GET /audits/87870/assessments HTTP/1.1",
#             "request_length": "4437",
#             "status": "200",
#             "bytes_sent": "2230",
#             "body_bytes_sent": "749",
#             "referrer": "https://atlas-copco-ab.projects-eu.highbond.com/audits/87870/objectives",
#             "user_agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36 Edg/120.0.0.0",
#             "request_time": "6.958",
#             "remote_user": "",
#             "x_nginx_id": "d8caf257dd555048e2fcd33a50b3ecee",
#             "x_request_id": "d8caf257dd555048e2fcd33a50b3ecee",
#             "upstream_status": "200",
#             "upstream_response_time": "6.956",
#             "upstream_connect_time": "0.000",
#             "upstream_header_time": "6.956"
#         },
#         "@ptr": "CmAKHgoaNzA3Nzg1Njg1MTcyOnByb2plY3RzLW1haW4QARI6GhgCBlq5/AMAAAAACHlXogAGWyJJIAAAAzIgASjOo/v+0zEw4/GC/9MxOIdIQL/d0QJI16AfUOrrHhgAIAEQ9i4YAQ=="
#     },
#     {
#         "@timestamp": "2024-01-25 09:07:16.930",
#         "@message": {
#             "time_local": "25/Jan/2024:09:07:16 +0000",
#             "client": "10.185.254.11",
#             "ACL_Cloudfront": "",
#             "method": "GET",
#             "scheme": "http",
#             "host": "deutsche-post-ag.projects-eu.highbond.com",
#             "request": "GET /audits/84050/assessments HTTP/1.1",
#             "request_length": "5046",
#             "status": "200",
#             "bytes_sent": "1539",
#             "body_bytes_sent": "58",
#             "referrer": "https://deutsche-post-ag.projects-eu.highbond.com/audits/84050/objectives",
#             "user_agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36",
#             "request_time": "6.117",
#             "remote_user": "",
#             "x_nginx_id": "ad86b6b16a82c6bafdc613f0c4e335ca",
#             "x_request_id": "ad86b6b16a82c6bafdc613f0c4e335ca",
#             "upstream_status": "200",
#             "upstream_response_time": "6.116",
#             "upstream_connect_time": "0.000",
#             "upstream_header_time": "6.116"
#         },
#         "@ptr": "CmAKHgoaNzA3Nzg1Njg1MTcyOnByb2plY3RzLW1haW4QARI6GhgCBlq5/AMAAAAACHlXogAGWyJJIAAAAzIgASjOo/v+0zEw4/GC/9MxOIdIQL/d0QJI16AfUOrrHhgAIAEQ9BkYAQ=="
#     },
#     {
#         "@timestamp": "2024-01-25 09:07:10.344",
#         "@message": {
#             "time_local": "25/Jan/2024:09:07:10 +0000",
#             "client": "10.185.255.210",
#             "ACL_Cloudfront": "",
#             "method": "POST",
#             "scheme": "http",
#             "host": "kenya-tea-development-agency-holdings-limited.projects-eu.highbond.com",
#             "request": "POST /controls/2642357/attachments HTTP/1.1",
#             "request_length": "886409",
#             "status": "200",
#             "bytes_sent": "3558",
#             "body_bytes_sent": "2091",
#             "referrer": "https://kenya-tea-development-agency-holdings-limited.projects-eu.highbond.com/audits/103846/objectives/446331/audit_plan_results/2160497",
#             "user_agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36",
#             "request_time": "5.970",
#             "remote_user": "",
#             "x_nginx_id": "a297b8fb3fd0fa42b8664ec13ba1899a",
#             "x_request_id": "a297b8fb3fd0fa42b8664ec13ba1899a",
#             "upstream_status": "200",
#             "upstream_response_time": "2.132",
#             "upstream_connect_time": "0.000",
#             "upstream_header_time": "2.128"
#         },
#         "@ptr": "CmAKHgoaNzA3Nzg1Njg1MTcyOnByb2plY3RzLW1haW4QARI6GhgCBlq5/AMAAAAACHlXogAGWyJJIAAAAzIgASjOo/v+0zEw4/GC/9MxOIdIQL/d0QJI16AfUOrrHhgAIAEQvxYYAQ=="
#     },
#     {
#         "@timestamp": "2024-01-25 09:05:46.380",
#         "@message": {
#             "time_local": "25/Jan/2024:09:05:46 +0000",
#             "client": "10.185.254.11",
#             "ACL_Cloudfront": "",
#             "method": "GET",
#             "scheme": "http",
#             "host": "absa-auditbond.projects-eu.highbond.com",
# ...
#             "upstream_header_time": "31.224"
#         },
#         "@ptr": "CmAKHgoaNzA3Nzg1Njg1MTcyOnByb2plY3RzLW1haW4QBhI6GhgCBlrlkzEAAAAAAtoPXAAGWyH+EAAAAhIgASjA97H+0zEwvoy5/tMxOIxYQImdzwNIuv0oUI3IKBgAIAEQyQEYAQ=="
#     },
#     {
#         "@timestamp": "2024-01-25 08:46:17.867",
#         "@message": {
#             "time_local": "25/Jan/2024:08:46:17 +0000",
#             "client": "10.185.255.210",
#             "ACL_Cloudfront": "",
#             "method": "GET",
#             "scheme": "http",
#             "host": "absa-auditbond.projects-eu.highbond.com",
#             "request": "GET /audits/56024/findings HTTP/1.1",
#             "request_length": "3644",
#             "status": "200",
#             "bytes_sent": "168136",
#             "body_bytes_sent": "166676",
#             "referrer": "https://absa-auditbond.projects-eu.highbond.com/audits/56024/findings/480507",
#             "user_agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36 Edg/120.0.0.0",
#             "request_time": "7.026",
#             "remote_user": "",
#             "x_nginx_id": "3a1c90729efa4ee2d2d812724f9e8231",
#             "x_request_id": "3a1c90729efa4ee2d2d812724f9e8231",
#             "upstream_status": "200",
#             "upstream_response_time": "7.028",
#             "upstream_connect_time": "0.000",
#             "upstream_header_time": "7.016"
#         },
#         "@ptr": "CmAKHgoaNzA3Nzg1Njg1MTcyOnByb2plY3RzLW1haW4QARI6GhgCBlq5/AMAAAAACHIx3gAGWyH70AAAAzIgASjv3q/+0zEwxuy3/tMxONBvQKeepgRIy+0vUKy3LxgAIAEQwRYYAQ=="
#     },
#     {
#         "@timestamp": "2024-01-25 08:45:52.729",
#         "@message": {
#             "time_local": "25/Jan/2024:08:45:52 +0000",
#             "client": "10.185.255.210",
#             "ACL_Cloudfront": "",
#             "method": "GET",
#             "scheme": "http",
#             "host": "projects-eu.highbond.com",
#             "request": "GET /api/v3/projects?org_id=4455&fields%5Bprojects%5D=custom_attributes%2Cattributes%2Ccollaborator_groups%2Ccollaborators%2Cname%2Cstate%2Cstatus%2Cplanned_start_date%2Cactual_start_date%2Cplanned_end_date%2Cactual_end_date%2Cplanned_milestone_date%2Cstart_date%2Ctarget_date%2Cactual_milestone_date&page%5Bsize%5D=100&page%5Bnumber%5D=MTE%3D HTTP/1.1",
#             "request_length": "4127",
#             "status": "200",
#             "bytes_sent": "135973",
#             "body_bytes_sent": "134943",
#             "referrer": "",
#             "user_agent": "RestSharp/107.3.0.0",
#             "request_time": "35.619",
#             "remote_user": "z.zohar@dhl.com",
#             "x_nginx_id": "c2ab4aa7f2f4103067c2e2a5a00af735",
#             "x_request_id": "6f1cfddfdc1ff3071b05db395f258bdd",
#             "upstream_status": "200",
#             "upstream_response_time": "35.619",
#             "upstream_connect_time": "0.000",
#             "upstream_header_time": "35.619"
#         },
#         "@ptr": "CmAKHgoaNzA3Nzg1Njg1MTcyOnByb2plY3RzLW1haW4QARI6GhgCBlq5/AMAAAAACHIx3gAGWyH70AAAAzIgASjv3q/+0zEwxuy3/tMxONBvQKeepgRIy+0vUKy3LxgAIAEQkgIYAQ=="
#     },
#     {
#         "@timestamp": "2024-01-25 08:45:40.326",
#         "@message": {
#             "time_local": "25/Jan/2024:08:45:40 +0000",
#             "client": "10.185.255.210",
#             "ACL_Cloudfront": "",
#             "method": "POST",
#             "scheme": "http",
#             "host": "afrocentrichealthlimited.projects-eu.highbond.com",
#             "request": "POST /findings/457147/attachments HTTP/1.1",
#             "request_length": "5038490",
#             "status": "200",
#             "bytes_sent": "3588",
#             "body_bytes_sent": "2121",
#             "referrer": "https://afrocentrichealthlimited.projects-eu.highbond.com/audits/93810/findings/457147",
#             "user_agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36 Edg/120.0.0.0",
#             "request_time": "5.252",
#             "remote_user": "",
#             "x_nginx_id": "e1cc5c1844898bf918d35c9317e79052",
#             "x_request_id": "e1cc5c1844898bf918d35c9317e79052",
#             "upstream_status": "200",
#             "upstream_response_time": "0.924",
#             "upstream_connect_time": "0.004",
#             "upstream_header_time": "0.924"
#         },
#         "@ptr": "CmAKHgoaNzA3Nzg1Njg1MTcyOnByb2plY3RzLW1haW4QARI6GhgCBlq5/AMAAAAACHFqbAAGWyHzwAAAAzIgASiI76f+0zEwwv2v/tMxOMRfQNO+8QNIkcUqUN6OKhgAIAEQlVgYAQ=="
#     },
#     {
#         "@timestamp": "2024-01-25 08:45:16.482",
#         "@message": {
#             "time_local": "25/Jan/2024:08:45:16 +0000",
#             "client": "10.185.254.11",
#             "ACL_Cloudfront": "",
#             "method": "GET",
#             "scheme": "http",
#             "host": "projects-eu.highbond.com",
#             "request": "GET /api/v3/projects?org_id=4455&fields%5Bprojects%5D=custom_attributes%2Cattributes%2Ccollaborator_groups%2Ccollaborators%2Cname%2Cstate%2Cstatus%2Cplanned_start_date%2Cactual_start_date%2Cplanned_end_date%2Cactual_end_date%2Cplanned_milestone_date%2Cstart_date%2Ctarget_date%2Cactual_milestone_date&page%5Bsize%5D=100&page%5Bnumber%5D=MTA%3D HTTP/1.1",
#             "request_length": "4125",
#             "status": "200",
#             "bytes_sent": "131399",
#             "body_bytes_sent": "130369",
#             "referrer": "",
#             "user_agent": "RestSharp/107.3.0.0",
#             "request_time": "30.999",
#             "remote_user": "z.zohar@dhl.com",
#             "x_nginx_id": "0553ae45b02b89770630a17ab964341a",
#             "x_request_id": "f7a1376583ecb1d82097852becfeae8e",
#             "upstream_status": "200",
#             "upstream_response_time": "31.000",
#             "upstream_connect_time": "0.004",
#             "upstream_header_time": "31.000"
#         },
#         "@ptr": "CmAKHgoaNzA3Nzg1Njg1MTcyOnByb2plY3RzLW1haW4QARI6GhgCBlq5/AMAAAAACHFqbAAGWyHzwAAAAzIgASiI76f+0zEwwv2v/tMxOMRfQNO+8QNIkcUqUN6OKhgAIAEQqEcYAQ=="
#     },
#     {
#         "@timestamp": "2024-01-25 08:44:45.081",
#         "@message": {
#             "time_local": "25/Jan/2024:08:44:45 +0000",
#             "client": "10.185.255.210",
#             "ACL_Cloudfront": "",
#             "method": "GET",
#             "scheme": "http",
#             "host": "projects-eu.highbond.com",
#             "request": "GET /api/v3/projects?org_id=4455&fields%5Bprojects%5D=custom_attributes%2Cattributes%2Ccollaborator_groups%2Ccollaborators%2Cname%2Cstate%2Cstatus%2Cplanned_start_date%2Cactual_start_date%2Cplanned_end_date%2Cactual_end_date%2Cplanned_milestone_date%2Cstart_date%2Ctarget_date%2Cactual_milestone_date&page%5Bsize%5D=100&page%5Bnumber%5D=OQ%3D%3D HTTP/1.1",
#             "request_length": "4129",
#             "status": "200",
#             "bytes_sent": "127366",
#             "body_bytes_sent": "126336",
#             "referrer": "",
#             "user_agent": "RestSharp/107.3.0.0",
#             "request_time": "30.830",
#             "remote_user": "z.zohar@dhl.com",
#             "x_nginx_id": "b23f81b967e0103a0f93341dd8690a35",
#             "x_request_id": "c3da38b03938d525f1001e205b05c735",
#             "upstream_status": "200",
#             "upstream_response_time": "30.828",
#             "upstream_connect_time": "0.000",
#             "upstream_header_time": "30.828"
#         },
#         "@ptr": "CmAKHgoaNzA3Nzg1Njg1MTcyOnByb2plY3RzLW1haW4QARI6GhgCBlq5/AMAAAAACHFqbAAGWyHzwAAAAzIgASiI76f+0zEwwv2v/tMxOMRfQNO+8QNIkcUqUN6OKhgAIAEQgDAYAQ=="
#     },
#     {
#         "@timestamp": "2024-01-25 08:44:14.025",
#         "@message": {
#             "time_local": "25/Jan/2024:08:44:14 +0000",
#             "client": "10.185.254.11",
#             "ACL_Cloudfront": "",
#             "method": "GET",
#             "scheme": "http",
#             "host": "projects-eu.highbond.com",
#             "request": "GET /api/v3/projects?org_id=4455&fields%5Bprojects%5D=custom_attributes%2Cattributes%2Ccollaborator_groups%2Ccollaborators%2Cname%2Cstate%2Cstatus%2Cplanned_start_date%2Cactual_start_date%2Cplanned_end_date%2Cactual_end_date%2Cplanned_milestone_date%2Cstart_date%2Ctarget_date%2Cactual_milestone_date&page%5Bsize%5D=100&page%5Bnumber%5D=OA%3D%3D HTTP/1.1",
#             "request_length": "4129",
#             "status": "200",
#             "bytes_sent": "132329",
#             "body_bytes_sent": "131299",
#             "referrer": "",
#             "user_agent": "RestSharp/107.3.0.0",
#             "request_time": "28.285",
#             "remote_user": "z.zohar@dhl.com",
#             "x_nginx_id": "a8737592d4f48ce28370e00c0453443c",
#             "x_request_id": "1eb16d259bef9763f360214ee9ffc8d8",
#             "upstream_status": "200",
#             "upstream_response_time": "28.285",
#             "upstream_connect_time": "0.004",
#             "upstream_header_time": "28.285"
#         },
#         "@ptr": "CmAKHgoaNzA3Nzg1Njg1MTcyOnByb2plY3RzLW1haW4QBxI6GhgCBlhyZIMAAAAArtvFiwAGWyHy8AAAAzIgASikiKf+0zEwvdCt/tMxOJ9PQKnr/wJImdIgUJmeIBgAIAEQlSYYAQ=="
#     },
#     {
#         "@timestamp": "2024-01-25 08:43:45.276",
#         "@message": {
#             "time_local": "25/Jan/2024:08:43:45 +0000",
#             "client": "10.185.254.11",
#             "ACL_Cloudfront": "",
#             "method": "GET",
#             "scheme": "http",
#             "host": "projects-eu.highbond.com",
#             "request": "GET /api/v3/projects?org_id=4455&fields%5Bprojects%5D=custom_attributes%2Cattributes%2Ccollaborator_groups%2Ccollaborators%2Cname%2Cstate%2Cstatus%2Cplanned_start_date%2Cactual_start_date%2Cplanned_end_date%2Cactual_end_date%2Cplanned_milestone_date%2Cstart_date%2Ctarget_date%2Cactual_milestone_date&page%5Bsize%5D=100&page%5Bnumber%5D=Nw%3D%3D HTTP/1.1",
#             "request_length": "4129",
#             "status": "200",
#             "bytes_sent": "130380",
#             "body_bytes_sent": "129350",
#             "referrer": "",
#             "user_agent": "RestSharp/107.3.0.0",
#             "request_time": "27.157",
#             "remote_user": "z.zohar@dhl.com",
#             "x_nginx_id": "17e3ebeff780c0bb5251585518178f0f",
#             "x_request_id": "c3588b873cbf7bda90e754c5edb7d5a5",
#             "upstream_status": "200",
#             "upstream_response_time": "27.156",
#             "upstream_connect_time": "0.000",
#             "upstream_header_time": "27.156"
#         },
#         "@ptr": "CmAKHgoaNzA3Nzg1Njg1MTcyOnByb2plY3RzLW1haW4QBBI6GhgCBlq7rBMAAAAAKSzhhgAGWyHxEAAAADIgASiPuqL+0zEwyYyt/tMxOMxgQLbI8ANI44krUOnTKhgAIAEQkCcYAQ=="
#     },
#     {
#         "@timestamp": "2024-01-25 08:43:30.047",
#         "@message": {
#             "time_local": "25/Jan/2024:08:43:30 +0000",
#             "client": "10.185.254.11",
#             "ACL_Cloudfront": "",
#             "method": "GET",
#             "scheme": "http",
#             "host": "ppcltd.projects-eu.highbond.com",
#             "request": "GET /audits/85784/assessments HTTP/1.1",
#             "request_length": "3715",
#             "status": "200",
#             "bytes_sent": "1539",
#             "body_bytes_sent": "58",
#             "referrer": "https://ppcltd.projects-eu.highbond.com/audits/85784/objectives",
#             "user_agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36 Edg/120.0.0.0",
#             "request_time": "6.730",
#             "remote_user": "",
#             "x_nginx_id": "a76c02ee61ec86c43eab79fc5dafcb9e",
#             "x_request_id": "a76c02ee61ec86c43eab79fc5dafcb9e",
#             "upstream_status": "200",
#             "upstream_response_time": "6.728",
#             "upstream_connect_time": "0.000",
#             "upstream_header_time": "6.728"
#         },
#         "@ptr": "CmAKHgoaNzA3Nzg1Njg1MTcyOnByb2plY3RzLW1haW4QARI6GhgCBlq5/AMAAAAACHCwIQAGWyHsAAAAAzIgASi/oKD+0zEwk4eo/tMxOLVfQIP4yANI/88oUOSaKBgAIAEQnFkYAQ=="
#     },
#     {
#         "@timestamp": "2024-01-25 08:43:17.466",
#         "@message": {
#             "time_local": "25/Jan/2024:08:43:17 +0000",
#             "client": "10.185.254.11",
#             "ACL_Cloudfront": "",
#             "method": "GET",
#             "scheme": "http",
#             "host": "projects-eu.highbond.com",
#             "request": "GET /api/v3/projects?org_id=4455&fields%5Bprojects%5D=custom_attributes%2Cattributes%2Ccollaborator_groups%2Ccollaborators%2Cname%2Cstate%2Cstatus%2Cplanned_start_date%2Cactual_start_date%2Cplanned_end_date%2Cactual_end_date%2Cplanned_milestone_date%2Cstart_date%2Ctarget_date%2Cactual_milestone_date&page%5Bsize%5D=100&page%5Bnumber%5D=Ng%3D%3D HTTP/1.1",
#             "request_length": "4129",
#             "status": "200",
#             "bytes_sent": "130014",
#             "body_bytes_sent": "128984",
#             "referrer": "",
#             "user_agent": "RestSharp/107.3.0.0",
#             "request_time": "32.621",
#             "remote_user": "z.zohar@dhl.com",
#             "x_nginx_id": "765aa54763a5f6a2ceb14c58cb1f1b75",
#             "x_request_id": "c73ef2f6abdcf163a28bc08ba56c30e4",
#             "upstream_status": "200",
#             "upstream_response_time": "32.620",
#             "upstream_connect_time": "0.000",
#             "upstream_header_time": "32.620"
#         },
#         "@ptr": "CmAKHgoaNzA3Nzg1Njg1MTcyOnByb2plY3RzLW1haW4QBhI6GhgCBlrlkzEAAAAAAtlZcAAGWyHv0AAAAhIgASjl9KL+0zEwuqCr/tMxOLBGQJvI1AJI/skfUNmUHxgAIAEQ3hgYAQ=="
#     },
#     {
#         "@timestamp": "2024-01-25 08:43:14.503",
#         "@message": {
#             "time_local": "25/Jan/2024:08:43:14 +0000",
#             "client": "10.185.255.210",
#             "ACL_Cloudfront": "",
#             "method": "POST",
#             "scheme": "http",
#             "host": "afrocentrichealthlimited.projects-eu.highbond.com",
#             "request": "POST /findings/457147/attachments HTTP/1.1",
#             "request_length": "5037209",
#             "status": "419",
#             "bytes_sent": "1064",
#             "body_bytes_sent": "104",
#             "referrer": "https://afrocentrichealthlimited.projects-eu.highbond.com/audits/93810/findings/457147",
#             "user_agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36 Edg/120.0.0.0",
#             "request_time": "7.162",
#             "remote_user": "",
#             "x_nginx_id": "5adefa3f1b7564a3ff6ee2a9314ebac2",
#             "x_request_id": "5adefa3f1b7564a3ff6ee2a9314ebac2",
#             "upstream_status": "419",
#             "upstream_response_time": "0.492",
#             "upstream_connect_time": "0.000",
#             "upstream_header_time": "0.492"
#         },
#         "@ptr": "CmAKHgoaNzA3Nzg1Njg1MTcyOnByb2plY3RzLW1haW4QAhI6GhgCBlisQSoAAAAAjTyEKwAGWyHu4AAAAqIgASiTkqP+0zEwxsqq/tMxOPtRQOGMngNIxe4kUMC4JBgAIAEQpSEYAQ=="
#     },
#     {
#         "@timestamp": "2024-01-25 08:42:44.686",
#         "@message": {
#             "time_local": "25/Jan/2024:08:42:44 +0000",
#             "client": "10.185.255.210",
#             "ACL_Cloudfront": "",
#             "method": "GET",
#             "scheme": "http",
#             "host": "projects-eu.highbond.com",
#             "request": "GET /api/v3/projects?org_id=4455&fields%5Bprojects%5D=custom_attributes%2Cattributes%2Ccollaborator_groups%2Ccollaborators%2Cname%2Cstate%2Cstatus%2Cplanned_start_date%2Cactual_start_date%2Cplanned_end_date%2Cactual_end_date%2Cplanned_milestone_date%2Cstart_date%2Ctarget_date%2Cactual_milestone_date&page%5Bsize%5D=100&page%5Bnumber%5D=NQ%3D%3D HTTP/1.1",
#             "request_length": "4129",
#             "status": "200",
#             "bytes_sent": "125558",
#             "body_bytes_sent": "124528",
#             "referrer": "",
#             "user_agent": "RestSharp/107.3.0.0",
#             "request_time": "31.511",
#             "remote_user": "z.zohar@dhl.com",
#             "x_nginx_id": "e6a742d80e74986809cc978818c8483d",
#             "x_request_id": "1ad2dc20cc69ffa66a51e568bfe6b721",
#             "upstream_status": "200",
#             "upstream_response_time": "31.512",
#             "upstream_connect_time": "0.004",
#             "upstream_header_time": "31.512"
#         },
#         "@ptr": "CmAKHgoaNzA3Nzg1Njg1MTcyOnByb2plY3RzLW1haW4QABI6GhgCBlr5WbwAAAAACOag9AAGWyHtsAAAAsIgASiI96H+0zEw+umo/tMxOK5WQOyYvgNIsdEmUKqbJhgAIAEQrSUYAQ=="
#     }
# ]

# %%
request_ids = collect_request_ids(data)

print (json.dumps(request_ids, indent=4))

# %% [markdown]
# # Collect All Requests and Aggregate on Total Duration

# %%
log_group = 'projects-main'
#log_group =  'api_proxy-main'
#log_group = 'results-main'

result = cloudwatch_query(logs_client, log_group, query, start_time=days_ago(3))

# Use ThreadPoolExecutor to run the loop in parallel
with ThreadPoolExecutor(max_workers=8) as executor:
    # Map the function to your request_ids
    results = executor.map(process_request, request_ids[:24])

    # Extend the data list with results from the threads
    for request_id,result in results:
        data[request_id] = result

print (json.dumps(data, indent=4))
